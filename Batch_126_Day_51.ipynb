# %% [markdown]
# <a href="https://colab.research.google.com/github/akarshpyr/Akarshcodes12/blob/main/Batch_126_Day_51.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Syllabus
# Introduction to data pre-processing using pandas, Data structures like series and data-frame. Indexing and data selection in series and data-frame. Concept of the need of data pre-processing, it’s importance and  basic, difference between structured and unstructured data." "Explore different options for data pre-processing.  Concept of numeric and categorical data features. Concept of handling duplicate and missing data. Concept of identifying anomalies in the data. Concept of data aggregations. Date and time related data manipulation. Different options of joining/merging data-frames. Concept of multi indexing, Concept of pivot tables.

# %% [markdown]
# ## How can one perform data preprocessing using Pandas?
#
# Data preprocessing can be performed using Pandas by importing the data into a Pandas DataFrame. Then the data can be cleaned by removing any rows or columns with null or incomplete data, and the data type of each column can be checked and converted to an appropriate data type. The data can then be normalized by using min-max scaling or z-score normalization. Finally, any outliers can be identified and removed.

# %% [markdown]
# ## What are Pandas Series and Data Frame?
#
# Pandas Series is a one-dimensional labeled array capable of holding data of any type. It is similar to a column in a spreadsheet or a one-dimensional array in NumPy.
#
# Pandas Data Frame is a two-dimensional labeled data structure with columns of potentially different types. It is similar to a spreadsheet or a table in SQL. It is the most commonly used pandas object.

# %% [markdown]
# ## Why is data preprocessing important before the main analysis?
#
# Data preprocessing is essential before the primary analysis because it prepares the data for analysis by making it more suitable for the analysis task. Preprocessing may involve data cleanings, such as removing noisy data, outliers, and inconsistencies. It may also include transforming the data into a more suitable form for the analysis task, such as normalizing, imputing missing values, and encoding categorical variables. Preprocessing can also reduce the complexity of the data and make it easier to interpret the results. Data preprocessing is essential for successful data analysis and machine learning.

# %% [markdown]
# ## What are the main options available for data pre-processing in Panda?
#
# 1. Cleaning: Removing null/missing values, duplicate values, etc.
# 2. Reshaping: Pivoting, melting, merging, etc.
# 3. Transformation: Applying mathematical functions, binning values, etc.
# 4. Normalizing/Scaling: Rescaling values to a common range.
# 5. Feature Engineering: Creating new features from existing data.

# %% [markdown]
# ## Compare structured and unstructured data.
#
# Structured data is organized in a specific way, such as in a database. It is organized systematically and follows a particular set of rules. Structured data is typically easier to analyze and search than unstructured data.
#
# Unstructured data is data that is not organized in any particular way. It may have no specific format or structure and is often found in text documents, images, audio, and video files. Unstructured data is often more challenging to analyze and search than structured data.

# %% [markdown]
# # What is data aggregation?
#
# Data aggregation is the process of combining data from multiple sources into a single, unified view. This process is used to create a summary of data from various sources, such as databases, files, or applications. Data aggregation can be used to analyze and draw insights from large data sets, as well as to create visualizations.

# %% [markdown]
# ## Compare numerical and categorical data features.
#
# Numerical data features are values or measurements expressed in numbers or numerical expressions, such as height, weight, age, or temperature.
#
# Categorical data features are values or measurements expressed in categories or classes, such as gender, nationality, or occupation.

# %% [markdown]
# ## How duplicate and missing data can be handled in Pandas?
#
# 1. Duplicate Data: To identify and remove duplicate data, the Pandas DataFrame.duplicated() method can be used. This will return a Boolean series indicating whether each row is a duplicate or not. The rows with True value are duplicates. To remove the duplicates, the Pandas DataFrame.drop_duplicates() method can be used.
#
# 2. Missing Data: Missing data can be handled by using the Pandas DataFrame.fillna() method to fill the missing values with a specific value. Alternatively, the Pandas DataFrame.dropna() method can be used to remove rows or columns with missing data.
#
# Note: See the example files.

# %% [markdown]
# ## How can anomalies be identified in Pandas?
#
# Anomalies can be identified in Pandas by using statistical methods such as standard deviation, min/max values, or boxplots. Additionally, Pandas also has a built-in feature for detecting outliers using the Z-score, which measures how many standard deviations a data point is from the mean.
#
# Note: See the example files.

# %% [markdown]
# ## Other Topics:
# 1. Date-time related data manipulation.
# 2. Joining and merging data frames.
# 3. Multi Indexing
# 4. Pivot Tables
#
# Note: See the example files.

# %% [markdown]
# 34-Aggregation.ipynb
#
# 29-Pivoting.ipynb
#
# 20-Hierarchical Indexing.ipynb
#
# 30-Duplicate-Values.ipynb

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/nyc_weather.csv')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.shape
# Out:
# (31, 11)

# %%
df.dtypes
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
df['Temperature'].values
# Out:
# array([38, 36, 40, 25, 20, 33, 39, 39, 44, 50, 33, 35, 26, 30, 43, 47, 36,
#        25, 22, 32, 31, 26, 26, 28, 34, 43, 41, 37, 36, 34, 46])

# %%
df = pd.to_datetime(df['EST'])

# %%
df1 = pd.Series(df)

# %%
data = pd.read_csv("/content/nyc_weather.csv")

# %%
data['EST_date'] = df1

# %%
data
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
data[['EST']][data['Events'] =='Rain']
# Out:
#           EST
# 8    1/9/2016
# 9   1/10/2016
# 15  1/16/2016
# 26  1/27/2016

# %%
data.isnull().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# EST_date                 0
# dtype: int64

# %%
col_list = list(data)

# %%
col_list
# Out:
# ['EST',
#  'Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'PrecipitationIn',
#  'CloudCover',
#  'Events',
#  'WindDirDegrees',
#  'EST_date']

# %%
len(col_list)
# Out:
# 12

# %%
col_list[0],col_list[11]= col_list[11] , col_list[0]

# %%
col_list
# Out:
# ['EST_date',
#  'Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'PrecipitationIn',
#  'CloudCover',
#  'Events',
#  'WindDirDegrees',
#  'EST']

# %%
data.columns = col_list

# %%
data
# Out:
#      EST_date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
data1 = pd.read_csv('/content/nyc_weather.csv')

# %%
data1
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
data1['est']= pd.to_datetime(data1['EST'])

# %%
data1
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
data1.drop('EST',axis=1)
# Out:
#     Temperature  DewPoint  Humidity  Sea Level PressureIn  VisibilityMiles  \
# 0            38        23        52                 30.03               10
# 1            36        18        46                 30.02               10
# 2            40        21        47                 29.86               10
# 3            25         9        44                 30.05               10
# 4            20        -3        41                 30.57               10
# 5            33         4        35                 30.50               10
# 6            39        11        33                 30.28               10
# 7            39        29        64                 30.20               10
# 8            44        38        77                 30.16                9
# 9            50        46        71                 29.59                4
# 10           33         8        37                 29.92               10
# ...

# %%
a = data1.est

# %%
a
# Out:
# 0    2016-01-01
# 1    2016-01-02
# 2    2016-01-03
# 3    2016-01-04
# 4    2016-01-05
# 5    2016-01-06
# 6    2016-01-07
# 7    2016-01-08
# 8    2016-01-09
# 9    2016-01-10
# 10   2016-01-11
# 11   2016-01-12
# 12   2016-01-13
# 13   2016-01-14
# 14   2016-01-15
# 15   2016-01-16
# 16   2016-01-17
# 17   2016-01-18
# 18   2016-01-19
# 19   2016-01-20
# 20   2016-01-21
# 21   2016-01-22
# 22   2016-01-23
# 23   2016-01-24
# 24   2016-01-25
# 25   2016-01-26
# 26   2016-01-27
# 27   2016-01-28
# 28   2016-01-29
# 29   2016-01-30
# 30   2016-01-31
# Name: est, dtype: datetime64[ns]

# %%
data1.insert(0,'EST_new',a,allow_duplicates=True)

# %%
data1
# Out:
#       EST_new        EST        EST  Temperature  DewPoint  Humidity  \
# 0  2016-01-01 2016-01-01   1/1/2016           38        23        52
# 1  2016-01-02 2016-01-02   1/2/2016           36        18        46
# 2  2016-01-03 2016-01-03   1/3/2016           40        21        47
# 3  2016-01-04 2016-01-04   1/4/2016           25         9        44
# 4  2016-01-05 2016-01-05   1/5/2016           20        -3        41
# 5  2016-01-06 2016-01-06   1/6/2016           33         4        35
# 6  2016-01-07 2016-01-07   1/7/2016           39        11        33
# 7  2016-01-08 2016-01-08   1/8/2016           39        29        64
# 8  2016-01-09 2016-01-09   1/9/2016           44        38        77
# 9  2016-01-10 2016-01-10  1/10/2016           50        46        71
# 10 2016-01-11 2016-01-11  1/11/2016           33         8        37
# 11 2016-01-12 2016-01-12  1/12/2016           35        15        53
# 12 2016-01-13 2016-01-13  1/13/2016           26         4        42
# ...

# %%
data_new = data1.drop(data1.columns[[1,2,13]],axis=1)

# %%
data_new
# Out:
#       EST_new  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  2016-01-01           38        23        52                 30.03
# 1  2016-01-02           36        18        46                 30.02
# 2  2016-01-03           40        21        47                 29.86
# 3  2016-01-04           25         9        44                 30.05
# 4  2016-01-05           20        -3        41                 30.57
# 5  2016-01-06           33         4        35                 30.50
# 6  2016-01-07           39        11        33                 30.28
# 7  2016-01-08           39        29        64                 30.20
# 8  2016-01-09           44        38        77                 30.16
# 9  2016-01-10           50        46        71                 29.59
# 10 2016-01-11           33         8        37                 29.92
# 11 2016-01-12           35        15        53                 29.85
# 12 2016-01-13           26         4        42                 29.94
# ...

# %%
data_new.shape
# Out:
# (31, 11)

# %%
data_new.set_index('EST_new')
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST_new
# 2016-01-01           38        23        52                 30.03
# 2016-01-02           36        18        46                 30.02
# 2016-01-03           40        21        47                 29.86
# 2016-01-04           25         9        44                 30.05
# 2016-01-05           20        -3        41                 30.57
# 2016-01-06           33         4        35                 30.50
# 2016-01-07           39        11        33                 30.28
# 2016-01-08           39        29        64                 30.20
# 2016-01-09           44        38        77                 30.16
# 2016-01-10           50        46        71                 29.59
# 2016-01-11           33         8        37                 29.92
# 2016-01-12           35        15        53                 29.85
# 2016-01-13           26         4        42                 29.94
# ...

# %%
data_new.dtypes
# Out:
# EST_new                 datetime64[ns]
# Temperature                      int64
# DewPoint                         int64
# Humidity                         int64
# Sea Level PressureIn           float64
# VisibilityMiles                  int64
# WindSpeedMPH                   float64
# PrecipitationIn                 object
# CloudCover                       int64
# Events                          object
# WindDirDegrees                   int64
# dtype: object

# %%
data_new
# Out:
#       EST_new  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  2016-01-01           38        23        52                 30.03
# 1  2016-01-02           36        18        46                 30.02
# 2  2016-01-03           40        21        47                 29.86
# 3  2016-01-04           25         9        44                 30.05
# 4  2016-01-05           20        -3        41                 30.57
# 5  2016-01-06           33         4        35                 30.50
# 6  2016-01-07           39        11        33                 30.28
# 7  2016-01-08           39        29        64                 30.20
# 8  2016-01-09           44        38        77                 30.16
# 9  2016-01-10           50        46        71                 29.59
# 10 2016-01-11           33         8        37                 29.92
# 11 2016-01-12           35        15        53                 29.85
# 12 2016-01-13           26         4        42                 29.94
# ...

# %%
data_new.isnull().sum()
# Out:
# EST_new                  0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
data_new['Events'].value_counts()
# Out:
# Rain        4
# Snow        3
# Fog-Snow    2
# Name: Events, dtype: int64

# %%
data_new['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
data_new['WindSpeedMPH'].fillna(6.892, inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_new
# Out:
#       EST_new  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  2016-01-01           38        23        52                 30.03
# 1  2016-01-02           36        18        46                 30.02
# 2  2016-01-03           40        21        47                 29.86
# 3  2016-01-04           25         9        44                 30.05
# 4  2016-01-05           20        -3        41                 30.57
# 5  2016-01-06           33         4        35                 30.50
# 6  2016-01-07           39        11        33                 30.28
# 7  2016-01-08           39        29        64                 30.20
# 8  2016-01-09           44        38        77                 30.16
# 9  2016-01-10           50        46        71                 29.59
# 10 2016-01-11           33         8        37                 29.92
# 11 2016-01-12           35        15        53                 29.85
# 12 2016-01-13           26         4        42                 29.94
# ...

# %%
data_new.isnull().sum()
# Out:
# EST_new                  0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             0
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
data_new[data_new.duplicated()]
# Out:
# Empty DataFrame
# Columns: [EST_new, Temperature, DewPoint, Humidity, Sea Level PressureIn, VisibilityMiles, WindSpeedMPH, PrecipitationIn, CloudCover, Events, WindDirDegrees]
# Index: []

# %%
data_new[['Temperature','Events']]
# Out:
#     Temperature    Events
# 0            38       NaN
# 1            36       NaN
# 2            40       NaN
# 3            25       NaN
# 4            20       NaN
# 5            33       NaN
# 6            39       NaN
# 7            39       NaN
# 8            44      Rain
# 9            50      Rain
# 10           33       NaN
# 11           35       NaN
# 12           26       NaN
# 13           30       NaN
# 14           43       NaN
# 15           47      Rain
# 16           36  Fog-Snow
# 17           25      Snow
# 18           22       NaN
# 19           32       NaN
# 20           31       NaN
# 21           26      Snow
# 22           26  Fog-Snow
# 23           28      Snow
# 24           34       NaN
# 25           43       NaN
# 26           41      Rain
# 27           37       NaN
# 28           36       NaN
# 29           34       NaN
# 30           46       NaN

# %%
wd = pd.read_csv('/content/weather_data.csv')

# %%
wd
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
wd['temperature'].fillna(wd['temperature'].mean(),inplace=True)
wd['windspeed'].fillna(wd['windspeed'].mean(),inplace=True)

# %%
wd
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         33.2        9.0   Sunny
# 2   1/5/2017         28.0        8.4    Snow
# 3   1/6/2017         33.2        7.0     NaN
# 4   1/7/2017         32.0        8.4    Rain
# 5   1/8/2017         33.2        8.4   Sunny
# 6   1/9/2017         33.2        8.4     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
wd['event'].fillna('Sunny',inplace=True)

# %%
wd
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         33.2        9.0   Sunny
# 2   1/5/2017         28.0        8.4    Snow
# 3   1/6/2017         33.2        7.0   Sunny
# 4   1/7/2017         32.0        8.4    Rain
# 5   1/8/2017         33.2        8.4   Sunny
# 6   1/9/2017         33.2        8.4   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# Concat will stack dataframes

# %%
wd.set_index('day',inplace=True)

# %%
wd
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          33.2        9.0   Sunny
# 1/5/2017          28.0        8.4    Snow
# 1/6/2017          33.2        7.0   Sunny
# 1/7/2017          32.0        8.4    Rain
# 1/8/2017          33.2        8.4   Sunny
# 1/9/2017          33.2        8.4   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# Use .fillna(dict) to fill the NaN values

# %%
#new_df = wd.interpolate()
asd = pd.read_csv('/content/weather_by_cities.csv')

# %%
asd
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
aa = asd.groupby('city')

# %%
aa

# %%
for city,asd in aa:
  print('city:',city)
  print()
  print('data:','\n',asd)
# Out:
# city: mumbai
#
# data:
#          day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# city: new york
#
# data:
#          day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# city: paris
#
# data:
#           day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
aa.get_group('paris')
# Out:
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
aa.count()
# Out:
#           day  temperature  windspeed  event
# city
# mumbai      4            4          4      4
# new york    4            4          4      4
# paris       4            4          4      4

# %%
aa.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
aa.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
asd.pivot(index='day',columns='event')
# Out:
#            city        temperature       windspeed
# event    Cloudy  Sunny      Cloudy Sunny    Cloudy Sunny
# day
# 1/1/2017    NaN  paris         NaN  45.0       NaN  20.0
# 1/2/2017  paris    NaN        50.0   NaN      13.0   NaN
# 1/3/2017  paris    NaN        54.0   NaN       8.0   NaN
# 1/4/2017  paris    NaN        42.0   NaN      10.0   NaN
