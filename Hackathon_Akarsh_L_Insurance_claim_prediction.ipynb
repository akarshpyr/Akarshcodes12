# %% [markdown]
# <a href="https://colab.research.google.com/github/akarshpyr/Akarshcodes12/blob/main/Hackathon_Akarsh_L_Insurance_claim_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Problem statement:
# InsureNow is a leading commercial Insurance provider with PAN India presence, The
# company wants to build a prediction algorithm based on a subset of data from 2002 to
# 2009.
# The company also wants to understand the data characteristics, so that it would help to
# negotiate better terms with the clients.

# %% [markdown]
# #Importing the required basic libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from functools import reduce

# %%
from pylab import rcParams
rcParams['figure.figsize'] = [14,10] #using rcParams to fix the visualization plot size. No need to call plt.figure() again to assign a figure size.
# %matplotlib inline 
#the plots will be displayed right next to the code neglecting the verbose.

# %% [markdown]
# Reading the train dataset

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Hackathon/Insurance_Claim_Info_data.csv') #reading the train data
df2 = pd.read_csv('/content/drive/MyDrive/Hackathon/Insurance_Date_data.csv')
df3 = pd.read_csv('/content/drive/MyDrive/Hackathon/Insurance_Result_data.csv')

# %%
df1
# Out:
#       Claim Number City Code       City             Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik      Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai          One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow      Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi         Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi          One Person Company
# ...            ...       ...        ...                         ...
# 34105   5CFGWQ6IR5       AGR       Agra      Public Limited Company
# 34106   QQ6EAWA4Q5       LKO    Lucknow            Partnership Firm
# 34107   X1J58PT1J5       HYD  Hyderabad          One Person Company
# 34108   AGOXXE8KII       MAA    Chennai         Sole Proprietorship
# 34109   WT5RH23GPC       LKO    Lucknow  Private Ltd. MSME - Medium
#
#             Claim Type  Claim Site                             Product Insured
# 0        Property Loss  In Transit                    Inventory - Raw Material
# 1        Property Loss  In Transit  Cameras and other Misc. Security Equipment
# 2        Property Loss  In Transit                                    Fixtures
# 3        Property Loss  In Transit                            Pumps and Motors
# 4        Property Loss  In Transit                     Misc. Engineering Tools
# ...                ...         ...                                         ...
# 34105    Property Loss  In Transit                     Misc. Engineering Tools
# 34106  Property Damage  In Transit                      Misc. Electronic Items
# 34107  Property Damage  In Transit                      Misc. Electronic Items
# 34108  Property Damage   Warehouse                            Pumps and Motors
# 34109    Property Loss  In Transit                    Inventory - Raw Material
#
# [34110 rows x 7 columns]

# %%
df2
# Out:
#       Claim Number Incident Date Date Received
# 0       BCHKRDM32K    21-10-2007    31-10-2007
# 1       B3GPD5IZQW    26-05-2006    14-06-2006
# 2       EB757CV6XW    18-01-2004    10-02-2004
# 3       SP0Z0Q95OV    28-04-2004    06-05-2004
# 4       VKZUK7J3KK    04-11-2007    14-11-2007
# ...            ...           ...           ...
# 34105   AF9GJPNKEX    04-11-2004    18-11-2004
# 34106   IB6C791V95    23-12-2005    23-02-2006
# 34107   PGEDMDDHC2    07-09-2007    11-09-2007
# 34108   MNSM4JN71E    05-12-2004    28-12-2004
# 34109   5YKXQ6YTNM    12-05-2007    24-09-2007
#
# [34110 rows x 3 columns]

# %%
df3
# Out:
#       Claim Number  Claim Amount  Close Amount      Disposition
# 0       Y5VA9KOE89        100.00          0.00             Deny
# 1       P51DOJLR8W        199.99          0.00             Deny
# 2       OUUZFP7EFL        410.00         59.85           Settle
# 3       CGP3L1CCP2        240.00          0.00             Deny
# 4       JDFLPD7J9Z         11.36         11.36  Approve in Full
# ...            ...           ...           ...              ...
# 34105   OYT2XKKCG7        400.00          0.00             Deny
# 34106   0WTU4L3YXH        380.80        142.00           Settle
# 34107   X9MZQW0X3Q         28.95         28.95  Approve in Full
# 34108   ITF3RPFW6L         75.15         75.15  Approve in Full
# 34109   A9G61X0801        299.00        149.50           Settle
#
# [34110 rows x 4 columns]

# %%
data_sets = [df1,df2,df3] #creating a list to merge datasets on common attribute

# %%
df_train = reduce(lambda left,right: pd.merge(left,right,on=['Claim Number'],how='outer'),data_sets) #using the reduce function which takes a fucntion and a list to perform merging action in one shot

# %%
df_train #merged train dataset
# Out:
#       Claim Number City Code       City             Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik      Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai          One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow      Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi         Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi          One Person Company
# ...            ...       ...        ...                         ...
# 34105   5CFGWQ6IR5       AGR       Agra      Public Limited Company
# 34106   QQ6EAWA4Q5       LKO    Lucknow            Partnership Firm
# 34107   X1J58PT1J5       HYD  Hyderabad          One Person Company
# 34108   AGOXXE8KII       MAA    Chennai         Sole Proprietorship
# 34109   WT5RH23GPC       LKO    Lucknow  Private Ltd. MSME - Medium
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34105    Property Loss  In Transit
# 34106  Property Damage  In Transit
# 34107  Property Damage  In Transit
# 34108  Property Damage   Warehouse
# 34109    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    25-05-2007    06-07-2007
# 1      Cameras and other Misc. Security Equipment    17-09-2006    27-09-2006
# 2                                        Fixtures    12-06-2006    17-07-2006
# 3                                Pumps and Motors    13-11-2005    05-12-2005
# 4                         Misc. Engineering Tools    28-07-2008    12-08-2008
# ...                                           ...           ...           ...
# 34105                     Misc. Engineering Tools    19-12-2005    21-03-2006
# 34106                      Misc. Electronic Items    08-01-2007    16-01-2007
# 34107                      Misc. Electronic Items    19-09-2005    18-10-2005
# 34108                            Pumps and Motors    14-04-2009    09-09-2009
# 34109                    Inventory - Raw Material    19-03-2005    29-03-2005
#
#        Claim Amount  Close Amount      Disposition
# 0            490.00          0.00             Deny
# 1            300.00        150.00           Settle
# 2             83.98         83.98  Approve in Full
# 3            507.88          0.00             Deny
# 4             83.46         41.73           Settle
# ...             ...           ...              ...
# 34105        238.00        115.60           Settle
# 34106          7.00          0.00             Deny
# 34107        166.00         70.00           Settle
# 34108        450.00        280.00           Settle
# 34109         70.35         70.35  Approve in Full
#
# [34110 rows x 12 columns]

# %% [markdown]
# #Exploratory data analysis

# %%
df_train.shape
# Out:
# (34110, 12)

# %%
df_train[df_train.duplicated()] #Checking for any duplicate rows
# Out:
# Empty DataFrame
# Columns: [Claim Number, City Code, City, Enterprise Type, Claim Type, Claim Site, Product Insured, Incident Date, Date Received, Claim Amount, Close Amount, Disposition]
# Index: []

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34110 entries, 0 to 34109
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Claim Number     34110 non-null  object
#  1   City Code        34110 non-null  object
#  2   City             34110 non-null  object
#  3   Enterprise Type  34110 non-null  object
#  4   Claim Type       34110 non-null  object
#  5   Claim Site       34110 non-null  object
#  6   Product Insured  34110 non-null  object
#  7   Incident Date    34110 non-null  object
#  8   Date Received    34110 non-null  object
#  9   Claim Amount     34110 non-null  float64
#  10  Close Amount     34110 non-null  float64
#  11  Disposition      34110 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 3.4+ MB

# %%
df_train.dtypes
# Out:
# Claim Number        object
# City Code           object
# City                object
# Enterprise Type     object
# Claim Type          object
# Claim Site          object
# Product Insured     object
# Incident Date       object
# Date Received       object
# Claim Amount       float64
# Close Amount       float64
# Disposition         object
# dtype: object

# %%
df_train.isnull().sum() #Checking the sum of null values in all the attributes
# Out:
# Claim Number       0
# City Code          0
# City               0
# Enterprise Type    0
# Claim Type         0
# Claim Site         0
# Product Insured    0
# Incident Date      0
# Date Received      0
# Claim Amount       0
# Close Amount       0
# Disposition        0
# dtype: int64

# %%
cols = df_train.columns

# %%
for i in cols:
  print(df_train[i].unique()) #checking for any foriegn symbols like /,<,?,!,@ etc.
# Out:
# ['DQW1NZO0PL' 'JS5GAPRN5B' 'ZTSVAQSEAQ' ... 'X1J58PT1J5' 'AGOXXE8KII'
#  'WT5RH23GPC']
# ['NSK' 'BOM' 'LKO' 'DEL' 'MAA' 'BDQ' 'ATQ' 'BLR' 'AMD' 'HYD' 'PAT' 'PNQ'
#  'CJB' 'JAI' 'KNU' 'IDR' 'CCU' 'VSK' 'THN' 'NGP' 'AGR' 'BHO' 'STV']
# ['Nashik' 'Mumbai' 'Lucknow' 'Delhi' 'Chennai' 'Vadodara' 'Amritsar'
#  'Bangalore' 'Ahmedabad' 'Hyderabad' 'Patna' 'Pune' 'Coimbatore' 'Jaipur'
#  'Kanpur' 'Indore' 'Kolkata' 'Visakhapatnam' 'Thane' 'Nagpur' 'Agra'
#  'Bhopal' 'Surat']
# ['Public Limited Company' 'One Person Company' 'Sole Proprietorship'
#  'Private Limited Company' 'Joint-Venture Company' 'Partnership Firm'
#  'Foreign Subsidary' 'Cooperative Society' 'Non-Profit Organization (NPO)'
#  'Private Ltd. MSME - Small' 'Private Ltd. MSME - Micro'
#  'Private Ltd. MSME - Medium' 'Limited Liability Parterneship (LLP)']
# ['Property Loss' 'Property Damage']
# ['In Transit' 'Warehouse' 'Other']
# ['Inventory - Raw Material' 'Cameras and other Misc. Security Equipment'
#  'Fixtures' 'Pumps and Motors' 'Misc. Engineering Tools'
#  'Misc. Electronic Items' 'Inventory - Finished Goods'
#  'Misc. Electrical Equipment' 'Furniture'
#  'Heating, ventilation, and air conditioning (HVAC) System'
#  'Misc. Sensors' 'Misc. Lab Equipment'
#  'Property, Plant, and Equipment (PPE) Parts']
# ['25-05-2007' '17-09-2006' '12-06-2006' ... '25-10-2002' '08-08-2002'
#  '04-10-2002']
# ['06-07-2007' '27-09-2006' '17-07-2006' ... '07-02-2002' '09-12-2003'
#  '12-12-2004']
# [  490.     300.      83.98 ...   103.5  51000.     312.93]
# [  0.   150.    83.98 ... 237.99 351.1  115.6 ]
# ['Deny' 'Settle' 'Approve in Full']

# %%
for i in cols:
  print(df_train[i].value_counts()) #We can check for the count of any inappropriate symbols like ?,/,#,@ etc
# Out:
# DQW1NZO0PL    1
# DE2D60203W    1
# AB5TC60CGU    1
# LKRGJJSQWY    1
# 6V7VLYE24D    1
#              ..
# 9JSDS56ZJA    1
# KI8SRQ9T0C    1
# JYCF0PS6UN    1
# UWETPATT05    1
# WT5RH23GPC    1
# Name: Claim Number, Length: 34110, dtype: int64
# BOM    2562
# DEL    2356
# BLR    2161
# HYD    2088
# MAA    1743
# PNQ    1705
# AMD    1692
# LKO    1646
# CCU    1583
# STV    1516
# JAI    1425
# KNU    1353
# NGP    1351
# IDR    1267
# CJB    1202
# THN    1182
# BHO    1161
# PAT    1088
# VSK    1084
# AGR    1036
# BDQ    1016
# NSK    1004
# ATQ     889
# Name: City Code, dtype: int64
# Mumbai           2562
# Delhi            2356
# Bangalore        2161
# Hyderabad        2088
# Chennai          1743
# Pune             1705
# Ahmedabad        1692
# Lucknow          1646
# Kolkata          1583
# Surat            1516
# Jaipur           1425
# Kanpur           1353
# Nagpur           1351
# Indore           1267
# Coimbatore       1202
# Thane            1182
# Bhopal           1161
# Patna            1088
# Visakhapatnam    1084
# Agra             1036
# Vadodara         1016
# Nashik           1004
# Amritsar          889
# Name: City, dtype: int64
# Sole Proprietorship                     6259
# One Person Company                      4910
# Private Limited Company                 4816
# Public Limited Company                  3903
# Joint-Venture Company                   3090
# Partnership Firm                        2838
# Non-Profit Organization (NPO)           2687
# Foreign Subsidary                       1662
# Private Ltd. MSME - Micro               1437
# Limited Liability Parterneship (LLP)     856
# Private Ltd. MSME - Medium               645
# Cooperative Society                      519
# Private Ltd. MSME - Small                488
# Name: Enterprise Type, dtype: int64
# Property Loss      21216
# Property Damage    12894
# Name: Claim Type, dtype: int64
# In Transit    28806
# Warehouse      5195
# Other           109
# Name: Claim Site, dtype: int64
# Inventory - Raw Material                                    8110
# Misc. Electronic Items                                      5611
# Misc. Engineering Tools                                     4247
# Inventory - Finished Goods                                  3322
# Furniture                                                   3034
# Misc. Electrical Equipment                                  2945
# Heating, ventilation, and air conditioning (HVAC) System    2787
# Fixtures                                                    1065
# Pumps and Motors                                            1025
# Misc. Lab Equipment                                          695
# Misc. Sensors                                                579
# Property, Plant, and Equipment (PPE) Parts                   347
# Cameras and other Misc. Security Equipment                   343
# Name: Product Insured, dtype: int64
# 19-04-2004    38
# 21-03-2004    37
# 08-01-2006    34
# 27-11-2004    34
# 21-05-2005    34
#               ..
# 30-04-2002     1
# 05-12-2009     1
# 24-11-2002     1
# 20-12-2009     1
# 04-10-2002     1
# Name: Incident Date, Length: 2685, dtype: int64
# 21-04-2004    215
# 27-05-2004    187
# 04-05-2004    154
# 05-12-2003    114
# 17-12-2003    112
#              ...
# 14-02-2004      1
# 19-05-2003      1
# 06-12-2008      1
# 24-12-2002      1
# 12-12-2004      1
# Name: Date Received, Length: 1832, dtype: int64
# 100.00     764
# 200.00     726
# 150.00     656
# 50.00      615
# 300.00     509
#           ...
# 889.00       1
# 1504.95      1
# 106.71       1
# 151.25       1
# 312.93       1
# Name: Claim Amount, Length: 11944, dtype: int64
# 0.00      17609
# 50.00      1186
# 100.00      358
# 25.00       298
# 20.00       293
#           ...
# 68.03         1
# 69.05         1
# 51.65         1
# 5.23          1
# 115.60        1
# Name: Close Amount, Length: 6509, dtype: int64
# Deny               17848
# Approve in Full     9052
# Settle              7210
# Name: Disposition, dtype: int64

# %%
df_train
# Out:
#       Claim Number City Code       City             Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik      Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai          One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow      Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi         Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi          One Person Company
# ...            ...       ...        ...                         ...
# 34105   5CFGWQ6IR5       AGR       Agra      Public Limited Company
# 34106   QQ6EAWA4Q5       LKO    Lucknow            Partnership Firm
# 34107   X1J58PT1J5       HYD  Hyderabad          One Person Company
# 34108   AGOXXE8KII       MAA    Chennai         Sole Proprietorship
# 34109   WT5RH23GPC       LKO    Lucknow  Private Ltd. MSME - Medium
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34105    Property Loss  In Transit
# 34106  Property Damage  In Transit
# 34107  Property Damage  In Transit
# 34108  Property Damage   Warehouse
# 34109    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    25-05-2007    06-07-2007
# 1      Cameras and other Misc. Security Equipment    17-09-2006    27-09-2006
# 2                                        Fixtures    12-06-2006    17-07-2006
# 3                                Pumps and Motors    13-11-2005    05-12-2005
# 4                         Misc. Engineering Tools    28-07-2008    12-08-2008
# ...                                           ...           ...           ...
# 34105                     Misc. Engineering Tools    19-12-2005    21-03-2006
# 34106                      Misc. Electronic Items    08-01-2007    16-01-2007
# 34107                      Misc. Electronic Items    19-09-2005    18-10-2005
# 34108                            Pumps and Motors    14-04-2009    09-09-2009
# 34109                    Inventory - Raw Material    19-03-2005    29-03-2005
#
#        Claim Amount  Close Amount      Disposition
# 0            490.00          0.00             Deny
# 1            300.00        150.00           Settle
# 2             83.98         83.98  Approve in Full
# 3            507.88          0.00             Deny
# 4             83.46         41.73           Settle
# ...             ...           ...              ...
# 34105        238.00        115.60           Settle
# 34106          7.00          0.00             Deny
# 34107        166.00         70.00           Settle
# 34108        450.00        280.00           Settle
# 34109         70.35         70.35  Approve in Full
#
# [34110 rows x 12 columns]

# %%
df_test = pd.read_excel('/content/drive/MyDrive/Hackathon/test_data-1663477366404.xlsx') #reading the test dataset

# %%
df_test
# Out:
#      Claim Number        Incident Date        Date Received City Code  \
# 0      6EYB31JGFR           21-09-2006           26-12-2006       PNQ
# 1      HJLRXONE3R           15-01-2009  2009-11-02 00:00:00       PNQ
# 2      IUOV99JA22           17-08-2005  2005-01-09 00:00:00       AMD
# 3      BGOUHQ2LKK           15-02-2005  2005-01-06 00:00:00       DEL
# 4      HDCG60QET1           17-03-2003  2003-01-04 00:00:00       PNQ
# ...           ...                  ...                  ...       ...
# 3786   IMQYY73AOP           30-07-2007           21-08-2007       CCU
# 3787   2AR1OGIMH4           21-08-2004  2004-09-09 00:00:00       NGP
# 3788   SB4IET2MO5           13-05-2005  2005-02-06 00:00:00       LKO
# 3789   3IBWXQK04L  2004-11-04 00:00:00  2004-04-05 00:00:00       BOM
# 3790   FK8SJ5GWYJ  2004-11-04 00:00:00           23-04-2004       BLR
#
#            City                       Enterprise Type       Claim Type  \
# 0          Pune                    One Person Company    Property Loss
# 1          Pune  Limited Liability Parterneship (LLP)    Property Loss
# 2     Ahmedabad               Private Limited Company    Property Loss
# 3         Delhi                    One Person Company  Property Damage
# 4          Pune               Private Limited Company  Property Damage
# ...         ...                                   ...              ...
# 3786    Kolkata               Private Limited Company    Property Loss
# 3787     Nagpur                   Sole Proprietorship    Property Loss
# 3788    Lucknow                 Joint-Venture Company    Property Loss
# 3789     Mumbai                    One Person Company  Property Damage
# 3790  Bangalore                Public Limited Company    Property Loss
#
#       Claim Site                                    Product Insured
# 0     In Transit                         Inventory - Finished Goods
# 1     In Transit                                           Fixtures
# 2      Warehouse                           Inventory - Raw Material
# 3     In Transit                         Inventory - Finished Goods
# 4     In Transit                             Misc. Electronic Items
# ...          ...                                                ...
# 3786   Warehouse         Cameras and other Misc. Security Equipment
# 3787  In Transit         Property, Plant, and Equipment (PPE) Parts
# 3788   Warehouse  Heating, ventilation, and air conditioning (HV...
# 3789  In Transit                             Misc. Electronic Items
# 3790  In Transit                                          Furniture
#
# [3791 rows x 9 columns]

# %%
df_train['Incident Date'] = pd.to_datetime(df_train['Incident Date'],infer_datetime_format=True) #converting to datetime format to carry out mathematical operations on dates
df_train['Date Received'] = pd.to_datetime(df_train['Date Received'],infer_datetime_format=True) #infer_datetime_format is used for consistent parsing with a format dd/mm/year
# Out:
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-09-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-07-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-11-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-10-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-06-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-06-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-04-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-02-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-11-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-07-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-07-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-11-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-08-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-06-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-11-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-12-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-12-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-12-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-11-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-07-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-08-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-11-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-12-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-04-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-01-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-06-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-01-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-05-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-08-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-05-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-07-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-12-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-07-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-01-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-10-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-07-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-12-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-08-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-11-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-08-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-11-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-05-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-01-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-08-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-09-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-08-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-06-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-11-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-03-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-02-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-05-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-10-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-08-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-11-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-06-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-11-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-10-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-09-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-03-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-12-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-06-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-08-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-03-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-06-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-09-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-11-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-11-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-08-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-10-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-02-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-04-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-09-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-06-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-08-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-10-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-12-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-07-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-03-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-06-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-01-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-02-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-09-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-01-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-10-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-05-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-03-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-12-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-09-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-04-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-05-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-05-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-10-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-08-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-12-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-10-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-11-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-09-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-04-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-07-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-05-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-09-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-06-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-01-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-02-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-05-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-06-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-05-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-04-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-05-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-09-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-01-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-09-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-05-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-01-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-08-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-05-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-10-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-07-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-11-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-01-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-06-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-07-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-09-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-12-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-10-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-01-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-08-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-08-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-06-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-08-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-11-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-10-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-07-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-10-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-12-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-07-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-02-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-05-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-06-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-08-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-06-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-11-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-04-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-06-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-08-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-04-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-08-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-03-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-08-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-11-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-07-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-04-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-08-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-11-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-06-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-06-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-02-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-01-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-05-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-05-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-05-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-08-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-10-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-05-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-05-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# ...
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-09-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-09-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-12-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-10-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-05-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-02-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-08-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-05-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-12-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-08-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-09-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-12-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-11-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-01-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-11-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-09-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-01-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-01-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-04-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-10-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-04-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '23-10-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-09-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '21-08-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-12-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-08-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-09-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-01-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-10-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-02-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-09-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-05-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-04-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-12-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-05-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-06-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-05-2055' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '26-07-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-08-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-12-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-04-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-10-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '29-06-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-08-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-07-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-06-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-12-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-04-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-10-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-05-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '31-03-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '13-11-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-08-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-07-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '14-10-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-10-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-08-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '24-05-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-05-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '16-08-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '22-04-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '27-05-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '19-11-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-08-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '30-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '25-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '18-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-01-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '17-02-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '20-02-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '28-08-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
# <ipython-input-285-59f356a4d7ea>:2: UserWarning:
#
# Parsing '15-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.

# %%
df_train.dtypes
# Out:
# Claim Number               object
# City Code                  object
# City                       object
# Enterprise Type            object
# Claim Type                 object
# Claim Site                 object
# Product Insured            object
# Incident Date      datetime64[ns]
# Date Received      datetime64[ns]
# Claim Amount              float64
# Close Amount              float64
# Disposition                object
# dtype: object

# %%
df_train
# Out:
#       Claim Number City Code       City             Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik      Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai          One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow      Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi         Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi          One Person Company
# ...            ...       ...        ...                         ...
# 34105   5CFGWQ6IR5       AGR       Agra      Public Limited Company
# 34106   QQ6EAWA4Q5       LKO    Lucknow            Partnership Firm
# 34107   X1J58PT1J5       HYD  Hyderabad          One Person Company
# 34108   AGOXXE8KII       MAA    Chennai         Sole Proprietorship
# 34109   WT5RH23GPC       LKO    Lucknow  Private Ltd. MSME - Medium
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34105    Property Loss  In Transit
# 34106  Property Damage  In Transit
# 34107  Property Damage  In Transit
# 34108  Property Damage   Warehouse
# 34109    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                                Pumps and Motors    2005-11-13    2005-05-12
# 4                         Misc. Engineering Tools    2008-07-28    2008-12-08
# ...                                           ...           ...           ...
# 34105                     Misc. Engineering Tools    2005-12-19    2006-03-21
# 34106                      Misc. Electronic Items    2007-01-08    2007-01-16
# 34107                      Misc. Electronic Items    2005-09-19    2005-10-18
# 34108                            Pumps and Motors    2009-04-14    2009-09-09
# 34109                    Inventory - Raw Material    2005-03-19    2005-03-29
#
#        Claim Amount  Close Amount      Disposition
# 0            490.00          0.00             Deny
# 1            300.00        150.00           Settle
# 2             83.98         83.98  Approve in Full
# 3            507.88          0.00             Deny
# 4             83.46         41.73           Settle
# ...             ...           ...              ...
# 34105        238.00        115.60           Settle
# 34106          7.00          0.00             Deny
# 34107        166.00         70.00           Settle
# 34108        450.00        280.00           Settle
# 34109         70.35         70.35  Approve in Full
#
# [34110 rows x 12 columns]

# %%
print("Incident_date_range:",df_train['Incident Date'].min(),'to',df_train['Incident Date'].max()) #Checking the range of the dates
print('Date received: ',df_train['Date Received'].min(),'to',df_train['Date Received'].max())
# Out:
# Incident_date_range: 2002-01-10 00:00:00 to 2010-06-22 00:00:00
# Date received:  1994-05-01 00:00:00 to 2055-05-17 00:00:00

# %%
df_train.describe() #descriptive statistics for numerical variables
# Out:
#         Claim Amount   Close Amount
# count   34110.000000   34110.000000
# mean      717.844178     104.883016
# std      8290.881802    1393.564677
# min         0.000000       0.000000
# 25%        60.000000       0.000000
# 50%       175.000000       0.000000
# 75%       460.000000      75.000000
# max    900000.000000  250000.000000

# %% [markdown]
# The claim amount cannot be zero as there are close amounts and dispositions associated with it.

# %%
df_train.describe(include='O') #Describing categorical variables
# Out:
#        Claim Number City Code    City      Enterprise Type     Claim Type  \
# count         34110     34110   34110                34110          34110
# unique        34110        23      23                   13              2
# top      DQW1NZO0PL       BOM  Mumbai  Sole Proprietorship  Property Loss
# freq              1      2562    2562                 6259          21216
#
#         Claim Site           Product Insured Disposition
# count        34110                     34110       34110
# unique           3                        13           3
# top     In Transit  Inventory - Raw Material        Deny
# freq         28806                      8110       17848

# %%
claim_zero = df_train.loc[df_train['Claim Amount']==0] #to check the claim amount which is zero

# %% [markdown]
# It is better to impute the claim amount to any value based on the type of Product insured to avoid misinterpretation of the model.

# %% [markdown]
# We can use the mean grouped by the product insured type to impute the zero values for the claim amount

# %%
product_df = pd.DataFrame(df_train.groupby('Product Insured')['Claim Amount'].mean())

# %%
product_df
# Out:
#                                                     Claim Amount
# Product Insured
# Cameras and other Misc. Security Equipment            293.572886
# Fixtures                                              188.192451
# Furniture                                            1523.551721
# Heating, ventilation, and air conditioning (HVA...   3230.923068
# Inventory - Finished Goods                             66.403721
# Inventory - Raw Material                              473.501813
# Misc. Electrical Equipment                            570.531691
# Misc. Electronic Items                                305.365126
# Misc. Engineering Tools                               448.261872
# Misc. Lab Equipment                                   815.774604
# Misc. Sensors                                         317.258048
# Property, Plant, and Equipment (PPE) Parts            334.126254
# Pumps and Motors                                      324.710029

# %%
claim_zero
# Out:
#       Claim Number City Code        City                Enterprise Type  \
# 823     7ZXPJ9Y8FS       LKO     Lucknow     Private Ltd. MSME - Medium
# 3322    QEGMQ6FFC2       BOM      Mumbai             One Person Company
# 3514    0SRXSQOEV2       LKO     Lucknow  Non-Profit Organization (NPO)
# 5174    2O8RR9LRD4       ATQ    Amritsar            Sole Proprietorship
# 16461   2T5DKNTRSG       CJB  Coimbatore          Joint-Venture Company
# 16872   CI4FIYW558       BDQ    Vadodara            Sole Proprietorship
# 17892   CYLO36MDGG       PNQ        Pune               Partnership Firm
# 19693   94KXFL2MNE       BDQ    Vadodara             One Person Company
# 19904   X3CF6XHWYN       BOM      Mumbai            Sole Proprietorship
# 24045   NVTSCVR89I       AGR        Agra             One Person Company
# 27188   XQWONIHXW0       PNQ        Pune             One Person Company
# 27932   OCMTNBLV9G       AMD   Ahmedabad      Private Ltd. MSME - Micro
# 28105   6XA8U75C17       AMD   Ahmedabad             One Person Company
# 32978   GF0BMJO8J8       THN       Thane             One Person Company
#
#             Claim Type  Claim Site  \
# 823      Property Loss  In Transit
# 3322     Property Loss  In Transit
# 3514     Property Loss  In Transit
# 5174     Property Loss  In Transit
# 16461  Property Damage  In Transit
# 16872    Property Loss   Warehouse
# 17892    Property Loss  In Transit
# 19693  Property Damage  In Transit
# 19904  Property Damage  In Transit
# 24045    Property Loss  In Transit
# 27188  Property Damage  In Transit
# 27932    Property Loss  In Transit
# 28105  Property Damage  In Transit
# 32978    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 823                      Inventory - Raw Material    2004-04-11    2004-04-23
# 3322                   Misc. Electrical Equipment    2004-09-08    2004-10-29
# 3514                     Inventory - Raw Material    2004-03-31    2004-04-23
# 5174                   Misc. Electrical Equipment    2004-04-23    2004-10-05
# 16461                  Misc. Electrical Equipment    2004-04-05    2004-03-06
# 16872                     Misc. Engineering Tools    2008-03-12    2008-05-13
# 17892  Property, Plant, and Equipment (PPE) Parts    2004-05-29    2004-06-07
# 19693                  Inventory - Finished Goods    2005-05-21    2005-07-20
# 19904                    Inventory - Raw Material    2004-04-17    2004-03-05
# 24045                    Inventory - Raw Material    2003-08-30    2003-09-29
# 27188                  Inventory - Finished Goods    2002-12-31    2003-02-13
# 27932                    Inventory - Raw Material    2004-03-18    2004-04-15
# 28105                  Inventory - Finished Goods    2005-05-09    2005-07-20
# 32978                     Misc. Engineering Tools    2005-01-28    2005-02-24
#
#        Claim Amount  Close Amount Disposition
# 823             0.0           0.0        Deny
# 3322            0.0           0.0        Deny
# 3514            0.0           0.0        Deny
# 5174            0.0           0.0        Deny
# 16461           0.0           0.0        Deny
# 16872           0.0           0.0        Deny
# 17892           0.0         165.0      Settle
# 19693           0.0           0.0        Deny
# 19904           0.0           0.0        Deny
# 24045           0.0           0.0        Deny
# 27188           0.0           0.0        Deny
# 27932           0.0           0.0        Deny
# 28105           0.0           0.0        Deny
# 32978           0.0         135.0      Settle

# %%
claim_zero.shape
# Out:
# (14, 12)

# %%
product_df = product_df.rename({'Claim Amount':'claim_amount_mean'},axis=1)

# %%
product_df
# Out:
#                                                     claim_amount_mean
# Product Insured
# Cameras and other Misc. Security Equipment                 293.572886
# Fixtures                                                   188.192451
# Furniture                                                 1523.551721
# Heating, ventilation, and air conditioning (HVA...        3230.923068
# Inventory - Finished Goods                                  66.403721
# Inventory - Raw Material                                   473.501813
# Misc. Electrical Equipment                                 570.531691
# Misc. Electronic Items                                     305.365126
# Misc. Engineering Tools                                    448.261872
# Misc. Lab Equipment                                        815.774604
# Misc. Sensors                                              317.258048
# Property, Plant, and Equipment (PPE) Parts                 334.126254
# Pumps and Motors                                           324.710029

# %%
df_traini = df_train

# %%
dfa = df_traini.loc[df_traini['Product Insured']=='Inventory - Raw Material'][df_traini['Claim Amount']==0]
# Out:
# <ipython-input-299-02f72c2fd089>:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
dfa
# Out:
#       Claim Number City Code       City                Enterprise Type  \
# 823     7ZXPJ9Y8FS       LKO    Lucknow     Private Ltd. MSME - Medium
# 3514    0SRXSQOEV2       LKO    Lucknow  Non-Profit Organization (NPO)
# 19904   X3CF6XHWYN       BOM     Mumbai            Sole Proprietorship
# 24045   NVTSCVR89I       AGR       Agra             One Person Company
# 27932   OCMTNBLV9G       AMD  Ahmedabad      Private Ltd. MSME - Micro
#
#             Claim Type  Claim Site           Product Insured Incident Date  \
# 823      Property Loss  In Transit  Inventory - Raw Material    2004-04-11
# 3514     Property Loss  In Transit  Inventory - Raw Material    2004-03-31
# 19904  Property Damage  In Transit  Inventory - Raw Material    2004-04-17
# 24045    Property Loss  In Transit  Inventory - Raw Material    2003-08-30
# 27932    Property Loss  In Transit  Inventory - Raw Material    2004-03-18
#
#       Date Received  Claim Amount  Close Amount Disposition
# 823      2004-04-23           0.0           0.0        Deny
# 3514     2004-04-23           0.0           0.0        Deny
# 19904    2004-03-05           0.0           0.0        Deny
# 24045    2003-09-29           0.0           0.0        Deny
# 27932    2004-04-15           0.0           0.0        Deny

# %%
dfa['Claim Amount'] = dfa['Claim Amount'].replace(0,473.50)

# %%
dfa
# Out:
#       Claim Number City Code       City                Enterprise Type  \
# 823     7ZXPJ9Y8FS       LKO    Lucknow     Private Ltd. MSME - Medium
# 3514    0SRXSQOEV2       LKO    Lucknow  Non-Profit Organization (NPO)
# 19904   X3CF6XHWYN       BOM     Mumbai            Sole Proprietorship
# 24045   NVTSCVR89I       AGR       Agra             One Person Company
# 27932   OCMTNBLV9G       AMD  Ahmedabad      Private Ltd. MSME - Micro
#
#             Claim Type  Claim Site           Product Insured Incident Date  \
# 823      Property Loss  In Transit  Inventory - Raw Material    2004-04-11
# 3514     Property Loss  In Transit  Inventory - Raw Material    2004-03-31
# 19904  Property Damage  In Transit  Inventory - Raw Material    2004-04-17
# 24045    Property Loss  In Transit  Inventory - Raw Material    2003-08-30
# 27932    Property Loss  In Transit  Inventory - Raw Material    2004-03-18
#
#       Date Received  Claim Amount  Close Amount Disposition
# 823      2004-04-23         473.5           0.0        Deny
# 3514     2004-04-23         473.5           0.0        Deny
# 19904    2004-03-05         473.5           0.0        Deny
# 24045    2003-09-29         473.5           0.0        Deny
# 27932    2004-04-15         473.5           0.0        Deny

# %%
dfb = df_traini.loc[df_traini['Product Insured']=='Misc. Electrical Equipment'][df_traini['Claim Amount']==0]
# Out:
# <ipython-input-303-1fce7b5d3593>:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
dfb['Claim Amount'] = dfb['Claim Amount'].replace(0,570.53)

# %%
dfb
# Out:
#       Claim Number City Code        City        Enterprise Type  \
# 3322    QEGMQ6FFC2       BOM      Mumbai     One Person Company
# 5174    2O8RR9LRD4       ATQ    Amritsar    Sole Proprietorship
# 16461   2T5DKNTRSG       CJB  Coimbatore  Joint-Venture Company
#
#             Claim Type  Claim Site             Product Insured Incident Date  \
# 3322     Property Loss  In Transit  Misc. Electrical Equipment    2004-09-08
# 5174     Property Loss  In Transit  Misc. Electrical Equipment    2004-04-23
# 16461  Property Damage  In Transit  Misc. Electrical Equipment    2004-04-05
#
#       Date Received  Claim Amount  Close Amount Disposition
# 3322     2004-10-29        570.53           0.0        Deny
# 5174     2004-10-05        570.53           0.0        Deny
# 16461    2004-03-06        570.53           0.0        Deny

# %%
dfc = df_traini.loc[df_traini['Product Insured']=='Inventory - Finished Goods'][df_traini['Claim Amount']==0]
# Out:
# <ipython-input-306-f15ab56cb337>:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
dfc['Claim Amount'] = dfc['Claim Amount'].replace(0,66.40)

# %%
dfd = df_traini.loc[df_traini['Product Insured']=='Misc. Engineering Tools'][df_traini['Claim Amount']==0]
# Out:
# <ipython-input-308-8c77d90ea5b4>:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
dfd['Claim Amount'] = dfd['Claim Amount'].replace(0,448.26)

# %%
dfe = df_traini.loc[df_traini['Product Insured']=='Property, Plant, and Equipment (PPE) Parts'][df_traini['Claim Amount']==0]
# Out:
# <ipython-input-310-a8418702ea7f>:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
dfe['Claim Amount'] = dfe['Claim Amount'].replace(0,334.12)

# %%
data_sets1 = [dfa,dfb,dfc,dfd,dfe]

# %%
df_zero =  reduce(lambda up,down: pd.concat([up,down],axis=0),data_sets1)

# %%
df_zero
# Out:
#       Claim Number City Code        City                Enterprise Type  \
# 823     7ZXPJ9Y8FS       LKO     Lucknow     Private Ltd. MSME - Medium
# 3514    0SRXSQOEV2       LKO     Lucknow  Non-Profit Organization (NPO)
# 19904   X3CF6XHWYN       BOM      Mumbai            Sole Proprietorship
# 24045   NVTSCVR89I       AGR        Agra             One Person Company
# 27932   OCMTNBLV9G       AMD   Ahmedabad      Private Ltd. MSME - Micro
# 3322    QEGMQ6FFC2       BOM      Mumbai             One Person Company
# 5174    2O8RR9LRD4       ATQ    Amritsar            Sole Proprietorship
# 16461   2T5DKNTRSG       CJB  Coimbatore          Joint-Venture Company
# 19693   94KXFL2MNE       BDQ    Vadodara             One Person Company
# 27188   XQWONIHXW0       PNQ        Pune             One Person Company
# 28105   6XA8U75C17       AMD   Ahmedabad             One Person Company
# 16872   CI4FIYW558       BDQ    Vadodara            Sole Proprietorship
# 32978   GF0BMJO8J8       THN       Thane             One Person Company
# 17892   CYLO36MDGG       PNQ        Pune               Partnership Firm
#
#             Claim Type  Claim Site  \
# 823      Property Loss  In Transit
# 3514     Property Loss  In Transit
# 19904  Property Damage  In Transit
# 24045    Property Loss  In Transit
# 27932    Property Loss  In Transit
# 3322     Property Loss  In Transit
# 5174     Property Loss  In Transit
# 16461  Property Damage  In Transit
# 19693  Property Damage  In Transit
# 27188  Property Damage  In Transit
# 28105  Property Damage  In Transit
# 16872    Property Loss   Warehouse
# 32978    Property Loss  In Transit
# 17892    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 823                      Inventory - Raw Material    2004-04-11    2004-04-23
# 3514                     Inventory - Raw Material    2004-03-31    2004-04-23
# 19904                    Inventory - Raw Material    2004-04-17    2004-03-05
# 24045                    Inventory - Raw Material    2003-08-30    2003-09-29
# 27932                    Inventory - Raw Material    2004-03-18    2004-04-15
# 3322                   Misc. Electrical Equipment    2004-09-08    2004-10-29
# 5174                   Misc. Electrical Equipment    2004-04-23    2004-10-05
# 16461                  Misc. Electrical Equipment    2004-04-05    2004-03-06
# 19693                  Inventory - Finished Goods    2005-05-21    2005-07-20
# 27188                  Inventory - Finished Goods    2002-12-31    2003-02-13
# 28105                  Inventory - Finished Goods    2005-05-09    2005-07-20
# 16872                     Misc. Engineering Tools    2008-03-12    2008-05-13
# 32978                     Misc. Engineering Tools    2005-01-28    2005-02-24
# 17892  Property, Plant, and Equipment (PPE) Parts    2004-05-29    2004-06-07
#
#        Claim Amount  Close Amount Disposition
# 823          473.50           0.0        Deny
# 3514         473.50           0.0        Deny
# 19904        473.50           0.0        Deny
# 24045        473.50           0.0        Deny
# 27932        473.50           0.0        Deny
# 3322         570.53           0.0        Deny
# 5174         570.53           0.0        Deny
# 16461        570.53           0.0        Deny
# 19693         66.40           0.0        Deny
# 27188         66.40           0.0        Deny
# 28105         66.40           0.0        Deny
# 16872        448.26           0.0        Deny
# 32978        448.26         135.0      Settle
# 17892        334.12         165.0      Settle

# %%
df_train.shape
# Out:
# (34110, 12)

# %%
df_train
# Out:
#       Claim Number City Code       City             Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik      Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai          One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow      Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi         Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi          One Person Company
# ...            ...       ...        ...                         ...
# 34105   5CFGWQ6IR5       AGR       Agra      Public Limited Company
# 34106   QQ6EAWA4Q5       LKO    Lucknow            Partnership Firm
# 34107   X1J58PT1J5       HYD  Hyderabad          One Person Company
# 34108   AGOXXE8KII       MAA    Chennai         Sole Proprietorship
# 34109   WT5RH23GPC       LKO    Lucknow  Private Ltd. MSME - Medium
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34105    Property Loss  In Transit
# 34106  Property Damage  In Transit
# 34107  Property Damage  In Transit
# 34108  Property Damage   Warehouse
# 34109    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                                Pumps and Motors    2005-11-13    2005-05-12
# 4                         Misc. Engineering Tools    2008-07-28    2008-12-08
# ...                                           ...           ...           ...
# 34105                     Misc. Engineering Tools    2005-12-19    2006-03-21
# 34106                      Misc. Electronic Items    2007-01-08    2007-01-16
# 34107                      Misc. Electronic Items    2005-09-19    2005-10-18
# 34108                            Pumps and Motors    2009-04-14    2009-09-09
# 34109                    Inventory - Raw Material    2005-03-19    2005-03-29
#
#        Claim Amount  Close Amount      Disposition
# 0            490.00          0.00             Deny
# 1            300.00        150.00           Settle
# 2             83.98         83.98  Approve in Full
# 3            507.88          0.00             Deny
# 4             83.46         41.73           Settle
# ...             ...           ...              ...
# 34105        238.00        115.60           Settle
# 34106          7.00          0.00             Deny
# 34107        166.00         70.00           Settle
# 34108        450.00        280.00           Settle
# 34109         70.35         70.35  Approve in Full
#
# [34110 rows x 12 columns]

# %%
data_frame = pd.concat([df_train,df_zero],axis=0)

# %%
data_frame.shape
# Out:
# (34124, 12)

# %%
data_frame = data_frame.dropna()

# %%
data_frame.shape
# Out:
# (34124, 12)

# %%
data_frame
# Out:
#       Claim Number City Code       City         Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik  Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai      One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow  Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi     Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi      One Person Company
# ...            ...       ...        ...                     ...
# 27188   XQWONIHXW0       PNQ       Pune      One Person Company
# 28105   6XA8U75C17       AMD  Ahmedabad      One Person Company
# 16872   CI4FIYW558       BDQ   Vadodara     Sole Proprietorship
# 32978   GF0BMJO8J8       THN      Thane      One Person Company
# 17892   CYLO36MDGG       PNQ       Pune        Partnership Firm
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 27188  Property Damage  In Transit
# 28105  Property Damage  In Transit
# 16872    Property Loss   Warehouse
# 32978    Property Loss  In Transit
# 17892    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                                Pumps and Motors    2005-11-13    2005-05-12
# 4                         Misc. Engineering Tools    2008-07-28    2008-12-08
# ...                                           ...           ...           ...
# 27188                  Inventory - Finished Goods    2002-12-31    2003-02-13
# 28105                  Inventory - Finished Goods    2005-05-09    2005-07-20
# 16872                     Misc. Engineering Tools    2008-03-12    2008-05-13
# 32978                     Misc. Engineering Tools    2005-01-28    2005-02-24
# 17892  Property, Plant, and Equipment (PPE) Parts    2004-05-29    2004-06-07
#
#        Claim Amount  Close Amount      Disposition
# 0            490.00          0.00             Deny
# 1            300.00        150.00           Settle
# 2             83.98         83.98  Approve in Full
# 3            507.88          0.00             Deny
# 4             83.46         41.73           Settle
# ...             ...           ...              ...
# 27188         66.40          0.00             Deny
# 28105         66.40          0.00             Deny
# 16872        448.26          0.00             Deny
# 32978        448.26        135.00           Settle
# 17892        334.12        165.00           Settle
#
# [34124 rows x 12 columns]

# %%
data_frame['Claim Amount'] = data_frame['Claim Amount'].replace(0,np.nan)

# %%
data1 = data_frame.dropna()

# %%
data1.shape
# Out:
# (34110, 12)

# %%
data1
# Out:
#       Claim Number City Code       City         Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik  Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai      One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow  Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi     Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi      One Person Company
# ...            ...       ...        ...                     ...
# 27188   XQWONIHXW0       PNQ       Pune      One Person Company
# 28105   6XA8U75C17       AMD  Ahmedabad      One Person Company
# 16872   CI4FIYW558       BDQ   Vadodara     Sole Proprietorship
# 32978   GF0BMJO8J8       THN      Thane      One Person Company
# 17892   CYLO36MDGG       PNQ       Pune        Partnership Firm
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 27188  Property Damage  In Transit
# 28105  Property Damage  In Transit
# 16872    Property Loss   Warehouse
# 32978    Property Loss  In Transit
# 17892    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                                Pumps and Motors    2005-11-13    2005-05-12
# 4                         Misc. Engineering Tools    2008-07-28    2008-12-08
# ...                                           ...           ...           ...
# 27188                  Inventory - Finished Goods    2002-12-31    2003-02-13
# 28105                  Inventory - Finished Goods    2005-05-09    2005-07-20
# 16872                     Misc. Engineering Tools    2008-03-12    2008-05-13
# 32978                     Misc. Engineering Tools    2005-01-28    2005-02-24
# 17892  Property, Plant, and Equipment (PPE) Parts    2004-05-29    2004-06-07
#
#        Claim Amount  Close Amount      Disposition
# 0            490.00          0.00             Deny
# 1            300.00        150.00           Settle
# 2             83.98         83.98  Approve in Full
# 3            507.88          0.00             Deny
# 4             83.46         41.73           Settle
# ...             ...           ...              ...
# 27188         66.40          0.00             Deny
# 28105         66.40          0.00             Deny
# 16872        448.26          0.00             Deny
# 32978        448.26        135.00           Settle
# 17892        334.12        165.00           Settle
#
# [34110 rows x 12 columns]

# %%
final_data = data1.reset_index(drop=True)

# %%
final_data
# Out:
#       Claim Number City Code       City         Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik  Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai      One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow  Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi     Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi      One Person Company
# ...            ...       ...        ...                     ...
# 34105   XQWONIHXW0       PNQ       Pune      One Person Company
# 34106   6XA8U75C17       AMD  Ahmedabad      One Person Company
# 34107   CI4FIYW558       BDQ   Vadodara     Sole Proprietorship
# 34108   GF0BMJO8J8       THN      Thane      One Person Company
# 34109   CYLO36MDGG       PNQ       Pune        Partnership Firm
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34105  Property Damage  In Transit
# 34106  Property Damage  In Transit
# 34107    Property Loss   Warehouse
# 34108    Property Loss  In Transit
# 34109    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                                Pumps and Motors    2005-11-13    2005-05-12
# 4                         Misc. Engineering Tools    2008-07-28    2008-12-08
# ...                                           ...           ...           ...
# 34105                  Inventory - Finished Goods    2002-12-31    2003-02-13
# 34106                  Inventory - Finished Goods    2005-05-09    2005-07-20
# 34107                     Misc. Engineering Tools    2008-03-12    2008-05-13
# 34108                     Misc. Engineering Tools    2005-01-28    2005-02-24
# 34109  Property, Plant, and Equipment (PPE) Parts    2004-05-29    2004-06-07
#
#        Claim Amount  Close Amount      Disposition
# 0            490.00          0.00             Deny
# 1            300.00        150.00           Settle
# 2             83.98         83.98  Approve in Full
# 3            507.88          0.00             Deny
# 4             83.46         41.73           Settle
# ...             ...           ...              ...
# 34105         66.40          0.00             Deny
# 34106         66.40          0.00             Deny
# 34107        448.26          0.00             Deny
# 34108        448.26        135.00           Settle
# 34109        334.12        165.00           Settle
#
# [34110 rows x 12 columns]

# %%
df_train2 = final_data

# %% [markdown]
# Filtering the data based on the client's requirement i.e. getting the observations between 2002 and 2009

# %%
final_data1 = df_train2.loc[(df_train2['Date Received']<='2009-12-31') & (df_train2['Date Received']>='2002-01-01')][(df_train2['Incident Date']<='2009-12-31') & (df_train2['Incident Date']>='2002-01-01')]
# Out:
# <ipython-input-329-7fd071069caa>:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
final_data1
# Out:
#       Claim Number City Code       City         Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik  Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai      One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow  Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi     Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi      One Person Company
# ...            ...       ...        ...                     ...
# 34105   XQWONIHXW0       PNQ       Pune      One Person Company
# 34106   6XA8U75C17       AMD  Ahmedabad      One Person Company
# 34107   CI4FIYW558       BDQ   Vadodara     Sole Proprietorship
# 34108   GF0BMJO8J8       THN      Thane      One Person Company
# 34109   CYLO36MDGG       PNQ       Pune        Partnership Firm
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34105  Property Damage  In Transit
# 34106  Property Damage  In Transit
# 34107    Property Loss   Warehouse
# 34108    Property Loss  In Transit
# 34109    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                                Pumps and Motors    2005-11-13    2005-05-12
# 4                         Misc. Engineering Tools    2008-07-28    2008-12-08
# ...                                           ...           ...           ...
# 34105                  Inventory - Finished Goods    2002-12-31    2003-02-13
# 34106                  Inventory - Finished Goods    2005-05-09    2005-07-20
# 34107                     Misc. Engineering Tools    2008-03-12    2008-05-13
# 34108                     Misc. Engineering Tools    2005-01-28    2005-02-24
# 34109  Property, Plant, and Equipment (PPE) Parts    2004-05-29    2004-06-07
#
#        Claim Amount  Close Amount      Disposition
# 0            490.00          0.00             Deny
# 1            300.00        150.00           Settle
# 2             83.98         83.98  Approve in Full
# 3            507.88          0.00             Deny
# 4             83.46         41.73           Settle
# ...             ...           ...              ...
# 34105         66.40          0.00             Deny
# 34106         66.40          0.00             Deny
# 34107        448.26          0.00             Deny
# 34108        448.26        135.00           Settle
# 34109        334.12        165.00           Settle
#
# [34105 rows x 12 columns]

# %%
final_data1['Days_for_claim_request'] = (final_data1['Date Received'] - final_data1['Incident Date']).dt.days

# %%
final_data1
# Out:
#       Claim Number City Code       City         Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik  Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai      One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow  Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi     Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi      One Person Company
# ...            ...       ...        ...                     ...
# 34105   XQWONIHXW0       PNQ       Pune      One Person Company
# 34106   6XA8U75C17       AMD  Ahmedabad      One Person Company
# 34107   CI4FIYW558       BDQ   Vadodara     Sole Proprietorship
# 34108   GF0BMJO8J8       THN      Thane      One Person Company
# 34109   CYLO36MDGG       PNQ       Pune        Partnership Firm
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34105  Property Damage  In Transit
# 34106  Property Damage  In Transit
# 34107    Property Loss   Warehouse
# 34108    Property Loss  In Transit
# 34109    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                                Pumps and Motors    2005-11-13    2005-05-12
# 4                         Misc. Engineering Tools    2008-07-28    2008-12-08
# ...                                           ...           ...           ...
# 34105                  Inventory - Finished Goods    2002-12-31    2003-02-13
# 34106                  Inventory - Finished Goods    2005-05-09    2005-07-20
# 34107                     Misc. Engineering Tools    2008-03-12    2008-05-13
# 34108                     Misc. Engineering Tools    2005-01-28    2005-02-24
# 34109  Property, Plant, and Equipment (PPE) Parts    2004-05-29    2004-06-07
#
#        Claim Amount  Close Amount      Disposition  Days_for_claim_request
# 0            490.00          0.00             Deny                      13
# 1            300.00        150.00           Settle                      10
# 2             83.98         83.98  Approve in Full                      35
# 3            507.88          0.00             Deny                    -185
# 4             83.46         41.73           Settle                     133
# ...             ...           ...              ...                     ...
# 34105         66.40          0.00             Deny                      44
# 34106         66.40          0.00             Deny                      72
# 34107        448.26          0.00             Deny                      62
# 34108        448.26        135.00           Settle                      27
# 34109        334.12        165.00           Settle                       9
#
# [34105 rows x 13 columns]

# %% [markdown]
# There seem to be negative values for days for requesting a claim which is impractical. It would be better to make those values absolute because there might be a chance of swapping incident date and receiving date during data entry.

# %%
final_data1.dtypes
# Out:
# Claim Number                      object
# City Code                         object
# City                              object
# Enterprise Type                   object
# Claim Type                        object
# Claim Site                        object
# Product Insured                   object
# Incident Date             datetime64[ns]
# Date Received             datetime64[ns]
# Claim Amount                     float64
# Close Amount                     float64
# Disposition                       object
# Days_for_claim_request             int64
# dtype: object

# %%
df_train3 = final_data1.loc[final_data1['Days_for_claim_request']>=0] #training dataset after imputing claim amount and filtering the dataset between 2002 and 2009

# %%
df_train3 #gives how many positive values of days required to request claim but other values cannot be ignored
# Out:
#       Claim Number City Code       City          Enterprise Type  \
# 0       DQW1NZO0PL       NSK     Nashik   Public Limited Company
# 1       JS5GAPRN5B       BOM     Mumbai       One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow   Public Limited Company
# 4       UJOFDC41EL       DEL      Delhi       One Person Company
# 5       IXZ4B1B9NO       MAA    Chennai  Private Limited Company
# ...            ...       ...        ...                      ...
# 34105   XQWONIHXW0       PNQ       Pune       One Person Company
# 34106   6XA8U75C17       AMD  Ahmedabad       One Person Company
# 34107   CI4FIYW558       BDQ   Vadodara      Sole Proprietorship
# 34108   GF0BMJO8J8       THN      Thane       One Person Company
# 34109   CYLO36MDGG       PNQ       Pune         Partnership Firm
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 4        Property Loss  In Transit
# 5        Property Loss  In Transit
# ...                ...         ...
# 34105  Property Damage  In Transit
# 34106  Property Damage  In Transit
# 34107    Property Loss   Warehouse
# 34108    Property Loss  In Transit
# 34109    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 4                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 5                         Misc. Engineering Tools    2004-09-21    2004-11-16
# ...                                           ...           ...           ...
# 34105                  Inventory - Finished Goods    2002-12-31    2003-02-13
# 34106                  Inventory - Finished Goods    2005-05-09    2005-07-20
# 34107                     Misc. Engineering Tools    2008-03-12    2008-05-13
# 34108                     Misc. Engineering Tools    2005-01-28    2005-02-24
# 34109  Property, Plant, and Equipment (PPE) Parts    2004-05-29    2004-06-07
#
#        Claim Amount  Close Amount      Disposition  Days_for_claim_request
# 0            490.00          0.00             Deny                      13
# 1            300.00        150.00           Settle                      10
# 2             83.98         83.98  Approve in Full                      35
# 4             83.46         41.73           Settle                     133
# 5             52.49         52.49  Approve in Full                      56
# ...             ...           ...              ...                     ...
# 34105         66.40          0.00             Deny                      44
# 34106         66.40          0.00             Deny                      72
# 34107        448.26          0.00             Deny                      62
# 34108        448.26        135.00           Settle                      27
# 34109        334.12        165.00           Settle                       9
#
# [28660 rows x 13 columns]

# %% [markdown]
# Swapping dates because there were more than 5400 negative days for days required to request claim

# %%
df_train4 = final_data1.loc[final_data1['Days_for_claim_request']<0]

# %%
df_train4
# Out:
#       Claim Number City Code        City         Enterprise Type  \
# 3       EW7NWHI7LI       DEL       Delhi     Sole Proprietorship
# 7       O9GKQUST4D       ATQ    Amritsar        Partnership Firm
# 12      0S0UBKY90M       MAA     Chennai     Sole Proprietorship
# 16      MNDBA5DU9T       BLR   Bangalore  Public Limited Company
# 22      W7GMRAJE0J       AMD   Ahmedabad  Public Limited Company
# ...            ...       ...         ...                     ...
# 34072   7OSAT7QFWV       CJB  Coimbatore   Joint-Venture Company
# 34075   C0Z4JCRRBX       PNQ        Pune  Public Limited Company
# 34080   83ZTMCMX9D       DEL       Delhi     Sole Proprietorship
# 34098   X3CF6XHWYN       BOM      Mumbai     Sole Proprietorship
# 34103   2T5DKNTRSG       CJB  Coimbatore   Joint-Venture Company
#
#             Claim Type  Claim Site             Product Insured Incident Date  \
# 3        Property Loss  In Transit            Pumps and Motors    2005-11-13
# 7      Property Damage  In Transit      Misc. Electronic Items    2008-05-19
# 12       Property Loss   Warehouse    Inventory - Raw Material    2005-07-13
# 16     Property Damage  In Transit                   Furniture    2004-07-28
# 22     Property Damage  In Transit    Inventory - Raw Material    2003-09-23
# ...                ...         ...                         ...           ...
# 34072    Property Loss  In Transit    Inventory - Raw Material    2005-10-22
# 34075  Property Damage  In Transit  Inventory - Finished Goods    2003-02-22
# 34080  Property Damage  In Transit      Misc. Electronic Items    2005-01-14
# 34098  Property Damage  In Transit    Inventory - Raw Material    2004-04-17
# 34103  Property Damage  In Transit  Misc. Electrical Equipment    2004-04-05
#
#       Date Received  Claim Amount  Close Amount      Disposition  \
# 3        2005-05-12        507.88          0.00             Deny
# 7        2008-01-07        372.27        313.14           Settle
# 12       2004-08-08        150.00          0.00             Deny
# 16       2004-01-10        300.00          0.00             Deny
# 22       2003-06-10       2500.00        928.89           Settle
# ...             ...           ...           ...              ...
# 34072    2005-09-11         28.50         28.50  Approve in Full
# 34075    2003-01-04        150.00        150.00             Deny
# 34080    2005-01-02        103.50         40.00           Settle
# 34098    2004-03-05        473.50          0.00             Deny
# 34103    2004-03-06        570.53          0.00             Deny
#
#        Days_for_claim_request
# 3                        -185
# 7                        -133
# 12                       -339
# 16                       -200
# 22                       -105
# ...                       ...
# 34072                     -41
# 34075                     -49
# 34080                     -12
# 34098                     -43
# 34103                     -30
#
# [5445 rows x 13 columns]

# %%
df_train4 = df_train4.rename({'Incident Date':'Date Received','Date Received':'Incident Date'},axis=1)
df_train4['Days_for_claim_request'] = abs(df_train4['Days_for_claim_request'])

# %%
df_train4
# Out:
#       Claim Number City Code        City         Enterprise Type  \
# 3       EW7NWHI7LI       DEL       Delhi     Sole Proprietorship
# 7       O9GKQUST4D       ATQ    Amritsar        Partnership Firm
# 12      0S0UBKY90M       MAA     Chennai     Sole Proprietorship
# 16      MNDBA5DU9T       BLR   Bangalore  Public Limited Company
# 22      W7GMRAJE0J       AMD   Ahmedabad  Public Limited Company
# ...            ...       ...         ...                     ...
# 34072   7OSAT7QFWV       CJB  Coimbatore   Joint-Venture Company
# 34075   C0Z4JCRRBX       PNQ        Pune  Public Limited Company
# 34080   83ZTMCMX9D       DEL       Delhi     Sole Proprietorship
# 34098   X3CF6XHWYN       BOM      Mumbai     Sole Proprietorship
# 34103   2T5DKNTRSG       CJB  Coimbatore   Joint-Venture Company
#
#             Claim Type  Claim Site             Product Insured Date Received  \
# 3        Property Loss  In Transit            Pumps and Motors    2005-11-13
# 7      Property Damage  In Transit      Misc. Electronic Items    2008-05-19
# 12       Property Loss   Warehouse    Inventory - Raw Material    2005-07-13
# 16     Property Damage  In Transit                   Furniture    2004-07-28
# 22     Property Damage  In Transit    Inventory - Raw Material    2003-09-23
# ...                ...         ...                         ...           ...
# 34072    Property Loss  In Transit    Inventory - Raw Material    2005-10-22
# 34075  Property Damage  In Transit  Inventory - Finished Goods    2003-02-22
# 34080  Property Damage  In Transit      Misc. Electronic Items    2005-01-14
# 34098  Property Damage  In Transit    Inventory - Raw Material    2004-04-17
# 34103  Property Damage  In Transit  Misc. Electrical Equipment    2004-04-05
#
#       Incident Date  Claim Amount  Close Amount      Disposition  \
# 3        2005-05-12        507.88          0.00             Deny
# 7        2008-01-07        372.27        313.14           Settle
# 12       2004-08-08        150.00          0.00             Deny
# 16       2004-01-10        300.00          0.00             Deny
# 22       2003-06-10       2500.00        928.89           Settle
# ...             ...           ...           ...              ...
# 34072    2005-09-11         28.50         28.50  Approve in Full
# 34075    2003-01-04        150.00        150.00             Deny
# 34080    2005-01-02        103.50         40.00           Settle
# 34098    2004-03-05        473.50          0.00             Deny
# 34103    2004-03-06        570.53          0.00             Deny
#
#        Days_for_claim_request
# 3                         185
# 7                         133
# 12                        339
# 16                        200
# 22                        105
# ...                       ...
# 34072                      41
# 34075                      49
# 34080                      12
# 34098                      43
# 34103                      30
#
# [5445 rows x 13 columns]

# %%
df_train5 = pd.concat([df_train3,df_train4],axis=0)
df_train5 = df_train5.reset_index(drop=True)

# %%
df_train5 #Dataset ready for training the model
# Out:
#       Claim Number City Code        City          Enterprise Type  \
# 0       DQW1NZO0PL       NSK      Nashik   Public Limited Company
# 1       JS5GAPRN5B       BOM      Mumbai       One Person Company
# 2       ZTSVAQSEAQ       LKO     Lucknow   Public Limited Company
# 3       UJOFDC41EL       DEL       Delhi       One Person Company
# 4       IXZ4B1B9NO       MAA     Chennai  Private Limited Company
# ...            ...       ...         ...                      ...
# 34100   7OSAT7QFWV       CJB  Coimbatore    Joint-Venture Company
# 34101   C0Z4JCRRBX       PNQ        Pune   Public Limited Company
# 34102   83ZTMCMX9D       DEL       Delhi      Sole Proprietorship
# 34103   X3CF6XHWYN       BOM      Mumbai      Sole Proprietorship
# 34104   2T5DKNTRSG       CJB  Coimbatore    Joint-Venture Company
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34100    Property Loss  In Transit
# 34101  Property Damage  In Transit
# 34102  Property Damage  In Transit
# 34103  Property Damage  In Transit
# 34104  Property Damage  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 4                         Misc. Engineering Tools    2004-09-21    2004-11-16
# ...                                           ...           ...           ...
# 34100                    Inventory - Raw Material    2005-09-11    2005-10-22
# 34101                  Inventory - Finished Goods    2003-01-04    2003-02-22
# 34102                      Misc. Electronic Items    2005-01-02    2005-01-14
# 34103                    Inventory - Raw Material    2004-03-05    2004-04-17
# 34104                  Misc. Electrical Equipment    2004-03-06    2004-04-05
#
#        Claim Amount  Close Amount      Disposition  Days_for_claim_request
# 0            490.00          0.00             Deny                      13
# 1            300.00        150.00           Settle                      10
# 2             83.98         83.98  Approve in Full                      35
# 3             83.46         41.73           Settle                     133
# 4             52.49         52.49  Approve in Full                      56
# ...             ...           ...              ...                     ...
# 34100         28.50         28.50  Approve in Full                      41
# 34101        150.00        150.00             Deny                      49
# 34102        103.50         40.00           Settle                      12
# 34103        473.50          0.00             Deny                      43
# 34104        570.53          0.00             Deny                      30
#
# [34105 rows x 13 columns]

# %%
df_settled = df_train5.loc[df_train5['Disposition']=='Settle']

# %%
df_settled
# Out:
#       Claim Number City Code       City         Enterprise Type  \
# 1       JS5GAPRN5B       BOM     Mumbai      One Person Company
# 3       UJOFDC41EL       DEL      Delhi      One Person Company
# 7       BPOBX1AAGE       AMD  Ahmedabad       Foreign Subsidary
# 11      CLUUJGQZ6M       PAT      Patna      One Person Company
# 18      1WRS1EREMN       JAI     Jaipur  Public Limited Company
# ...            ...       ...        ...                     ...
# 34083   LZWRGZS64I       NSK     Nashik        Partnership Firm
# 34084   K9XIM013FB       BDQ   Vadodara      One Person Company
# 34098   YNQEXYCQOG       MAA    Chennai     Sole Proprietorship
# 34099   OWLZK3EQ6N       ATQ   Amritsar        Partnership Firm
# 34102   83ZTMCMX9D       DEL      Delhi     Sole Proprietorship
#
#             Claim Type  Claim Site  \
# 1        Property Loss  In Transit
# 3        Property Loss  In Transit
# 7      Property Damage  In Transit
# 11       Property Loss  In Transit
# 18       Property Loss  In Transit
# ...                ...         ...
# 34083    Property Loss  In Transit
# 34084  Property Damage  In Transit
# 34098    Property Loss  In Transit
# 34099    Property Loss  In Transit
# 34102  Property Damage  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 3                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 7                          Misc. Electronic Items    2004-06-05    2004-06-29
# 11                        Misc. Engineering Tools    2006-06-21    2006-06-22
# 18                     Misc. Electrical Equipment    2004-01-14    2004-02-23
# ...                                           ...           ...           ...
# 34083                  Misc. Electrical Equipment    2003-06-11    2003-10-17
# 34084                  Misc. Electrical Equipment    2004-05-08    2004-07-15
# 34098                     Misc. Engineering Tools    2003-09-12    2003-11-28
# 34099                    Inventory - Raw Material    2003-06-10    2003-09-02
# 34102                      Misc. Electronic Items    2005-01-02    2005-01-14
#
#        Claim Amount  Close Amount Disposition  Days_for_claim_request
# 1            300.00        150.00      Settle                      10
# 3             83.46         41.73      Settle                     133
# 7            500.00         50.00      Settle                      24
# 11           100.00         50.00      Settle                       1
# 18           786.00        456.31      Settle                      40
# ...             ...           ...         ...                     ...
# 34083        849.69        424.85      Settle                     128
# 34084        416.90        275.38      Settle                      68
# 34098        350.00        175.00      Settle                      77
# 34099         20.00         10.00      Settle                      84
# 34102        103.50         40.00      Settle                      12
#
# [7208 rows x 13 columns]

# %%
df_settled = df_settled.rename({'Close Amount':'close_amount','Claim Amount':'claim_amount'},axis=1)

# %%
df_settled['Perc_of_settl_amount'] = round(df_settled.eval('close_amount/claim_amount')*100,2)

# %% [markdown]
# Using eval and round functions to make the calculation simpler

# %%
df_settled
# Out:
#       Claim Number City Code       City         Enterprise Type  \
# 1       JS5GAPRN5B       BOM     Mumbai      One Person Company
# 3       UJOFDC41EL       DEL      Delhi      One Person Company
# 7       BPOBX1AAGE       AMD  Ahmedabad       Foreign Subsidary
# 11      CLUUJGQZ6M       PAT      Patna      One Person Company
# 18      1WRS1EREMN       JAI     Jaipur  Public Limited Company
# ...            ...       ...        ...                     ...
# 34083   LZWRGZS64I       NSK     Nashik        Partnership Firm
# 34084   K9XIM013FB       BDQ   Vadodara      One Person Company
# 34098   YNQEXYCQOG       MAA    Chennai     Sole Proprietorship
# 34099   OWLZK3EQ6N       ATQ   Amritsar        Partnership Firm
# 34102   83ZTMCMX9D       DEL      Delhi     Sole Proprietorship
#
#             Claim Type  Claim Site  \
# 1        Property Loss  In Transit
# 3        Property Loss  In Transit
# 7      Property Damage  In Transit
# 11       Property Loss  In Transit
# 18       Property Loss  In Transit
# ...                ...         ...
# 34083    Property Loss  In Transit
# 34084  Property Damage  In Transit
# 34098    Property Loss  In Transit
# 34099    Property Loss  In Transit
# 34102  Property Damage  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 3                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 7                          Misc. Electronic Items    2004-06-05    2004-06-29
# 11                        Misc. Engineering Tools    2006-06-21    2006-06-22
# 18                     Misc. Electrical Equipment    2004-01-14    2004-02-23
# ...                                           ...           ...           ...
# 34083                  Misc. Electrical Equipment    2003-06-11    2003-10-17
# 34084                  Misc. Electrical Equipment    2004-05-08    2004-07-15
# 34098                     Misc. Engineering Tools    2003-09-12    2003-11-28
# 34099                    Inventory - Raw Material    2003-06-10    2003-09-02
# 34102                      Misc. Electronic Items    2005-01-02    2005-01-14
#
#        claim_amount  close_amount Disposition  Days_for_claim_request  \
# 1            300.00        150.00      Settle                      10
# 3             83.46         41.73      Settle                     133
# 7            500.00         50.00      Settle                      24
# 11           100.00         50.00      Settle                       1
# 18           786.00        456.31      Settle                      40
# ...             ...           ...         ...                     ...
# 34083        849.69        424.85      Settle                     128
# 34084        416.90        275.38      Settle                      68
# 34098        350.00        175.00      Settle                      77
# 34099         20.00         10.00      Settle                      84
# 34102        103.50         40.00      Settle                      12
#
#        Perc_of_settl_amount
# 1                     50.00
# 3                     50.00
# 7                     10.00
# 11                    50.00
# 18                    58.05
# ...                     ...
# 34083                 50.00
# 34084                 66.05
# 34098                 50.00
# 34099                 50.00
# 34102                 38.65
#
# [7208 rows x 14 columns]

# %%
df_settled.loc[df_settled['Perc_of_settl_amount']>100] #There are settlement amounts more than 100% which is strange but have to considered as bank already have processed the amount
# Out:
#       Claim Number City Code           City                Enterprise Type  \
# 9789    J5LV2O1UWF       VSK  Visakhapatnam            Cooperative Society
# 13955   BGCQY13XUK       JAI         Jaipur               Partnership Firm
# 18186   050DTUFNW0       STV          Surat  Non-Profit Organization (NPO)
# 20271   AF0ETBMUNV       BOM         Mumbai               Partnership Firm
# 30153   VG920NOB6R       HYD      Hyderabad        Private Limited Company
#
#           Claim Type  Claim Site             Product Insured Incident Date  \
# 9789   Property Loss  In Transit    Inventory - Raw Material    2005-12-05
# 13955  Property Loss  In Transit  Misc. Electrical Equipment    2007-09-19
# 18186  Property Loss  In Transit     Misc. Engineering Tools    2004-09-07
# 20271  Property Loss  In Transit    Inventory - Raw Material    2005-05-01
# 30153  Property Loss  In Transit    Inventory - Raw Material    2004-04-06
#
#       Date Received  claim_amount  close_amount Disposition  \
# 9789     2006-03-02        188.00        194.00      Settle
# 13955    2007-11-10        279.65        286.57      Settle
# 18186    2004-09-23        249.99        259.81      Settle
# 20271    2005-05-13         48.00        144.77      Settle
# 30153    2004-05-06        119.00        234.00      Settle
#
#        Days_for_claim_request  Perc_of_settl_amount
# 9789                       87                103.19
# 13955                      52                102.47
# 18186                      16                103.93
# 20271                      12                301.60
# 30153                      30                196.64

# %%
settled_mean = round(df_settled['Perc_of_settl_amount'].mean(),2)

# %%
settled_mean
# Out:
# 50.25

# %% [markdown]
# #What is the average % of claims received when the claim is 'Settled' ?

# %%
print(f"The average % of claims received when the claim is 'Settled' is {settled_mean}%")
# Out:
# The average % of claims received when the claim is 'Settled' is 50.25%

# %% [markdown]
# #Which 'Product' has the highest delay in Reporting (In days) ?

# %% [markdown]
# If there are negative values in the reporting delay days transform those into positive values assuming that there is a data entry error while entering the incident date and claim request date. (It might have been swapped, hence taking the absolute values.)

# %%
data3 = df_train5.copy()

# %%
data3
# Out:
#       Claim Number City Code        City          Enterprise Type  \
# 0       DQW1NZO0PL       NSK      Nashik   Public Limited Company
# 1       JS5GAPRN5B       BOM      Mumbai       One Person Company
# 2       ZTSVAQSEAQ       LKO     Lucknow   Public Limited Company
# 3       UJOFDC41EL       DEL       Delhi       One Person Company
# 4       IXZ4B1B9NO       MAA     Chennai  Private Limited Company
# ...            ...       ...         ...                      ...
# 34100   7OSAT7QFWV       CJB  Coimbatore    Joint-Venture Company
# 34101   C0Z4JCRRBX       PNQ        Pune   Public Limited Company
# 34102   83ZTMCMX9D       DEL       Delhi      Sole Proprietorship
# 34103   X3CF6XHWYN       BOM      Mumbai      Sole Proprietorship
# 34104   2T5DKNTRSG       CJB  Coimbatore    Joint-Venture Company
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34100    Property Loss  In Transit
# 34101  Property Damage  In Transit
# 34102  Property Damage  In Transit
# 34103  Property Damage  In Transit
# 34104  Property Damage  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 4                         Misc. Engineering Tools    2004-09-21    2004-11-16
# ...                                           ...           ...           ...
# 34100                    Inventory - Raw Material    2005-09-11    2005-10-22
# 34101                  Inventory - Finished Goods    2003-01-04    2003-02-22
# 34102                      Misc. Electronic Items    2005-01-02    2005-01-14
# 34103                    Inventory - Raw Material    2004-03-05    2004-04-17
# 34104                  Misc. Electrical Equipment    2004-03-06    2004-04-05
#
#        Claim Amount  Close Amount      Disposition  Days_for_claim_request
# 0            490.00          0.00             Deny                      13
# 1            300.00        150.00           Settle                      10
# 2             83.98         83.98  Approve in Full                      35
# 3             83.46         41.73           Settle                     133
# 4             52.49         52.49  Approve in Full                      56
# ...             ...           ...              ...                     ...
# 34100         28.50         28.50  Approve in Full                      41
# 34101        150.00        150.00             Deny                      49
# 34102        103.50         40.00           Settle                      12
# 34103        473.50          0.00             Deny                      43
# 34104        570.53          0.00             Deny                      30
#
# [34105 rows x 13 columns]

# %%
prod_d = pd.DataFrame(data3.groupby('Product Insured')['Days_for_claim_request'].mean())

# %%
prod_d
# Out:
#                                                     Days_for_claim_request
# Product Insured
# Cameras and other Misc. Security Equipment                       63.247813
# Fixtures                                                         70.955869
# Furniture                                                        79.023731
# Heating, ventilation, and air conditioning (HVA...               83.239411
# Inventory - Finished Goods                                       73.277627
# Inventory - Raw Material                                         76.817094
# Misc. Electrical Equipment                                       75.070289
# Misc. Electronic Items                                           83.268627
# Misc. Engineering Tools                                          75.434895
# Misc. Lab Equipment                                              75.398561
# Misc. Sensors                                                    73.317789
# Property, Plant, and Equipment (PPE) Parts                       84.916427
# Pumps and Motors                                                 77.116098

# %%
prod_d['Days_for_claim_request'] = round(prod_d['Days_for_claim_request'],0)

# %%
prod_d
# Out:
#                                                     Days_for_claim_request
# Product Insured
# Cameras and other Misc. Security Equipment                            63.0
# Fixtures                                                              71.0
# Furniture                                                             79.0
# Heating, ventilation, and air conditioning (HVA...                    83.0
# Inventory - Finished Goods                                            73.0
# Inventory - Raw Material                                              77.0
# Misc. Electrical Equipment                                            75.0
# Misc. Electronic Items                                                83.0
# Misc. Engineering Tools                                               75.0
# Misc. Lab Equipment                                                   75.0
# Misc. Sensors                                                         73.0
# Property, Plant, and Equipment (PPE) Parts                            85.0
# Pumps and Motors                                                      77.0

# %%
fig1 = px.bar(prod_d,text_auto=True)
fig1.update_layout(title='Which Product has the highest delay in Reporting (In days)',xaxis_title='Type of products',yaxis_title='Average days of delay reporting',font=dict(
        family="TimesNewRoman",
        size=16,
        color="Black"))
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="276c6d30-e4c5-44e0-ad1f-2e62e92d951a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("276c6d30-e4c5-44e0-ad1f-2e62e92d951a")) {                    Plotly.newPlot(                        "276c6d30-e4c5-44e0-ad1f-2e62e92d951a",                        [{"alignmentgroup":"True","hovertemplate":"variable=Days_for_claim_request<br>Product Insured=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Days_for_claim_request","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Days_for_claim_request","offsetgroup":"Days_for_claim_request","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Cameras and other Misc. Security Equipment","Fixtures","Furniture","Heating, ventilation, and air conditioning (HVAC) System","Inventory - Finished Goods","Inventory - Raw Material","Misc. Electrical Equipment","Misc. Electronic Items","Misc. Engineering Tools","Misc. Lab Equipment","Misc. Sensors","Property, Plant, and Equipment (PPE) Parts","Pumps and Motors"],"xaxis":"x","y":[63.0,71.0,79.0,83.0,73.0,77.0,75.0,83.0,75.0,75.0,73.0,85.0,77.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatte ...

# %% [markdown]
# **Insights:**
#
# *   We can see that Property, Plant, and Equipment (PPE) Parts have the highest delay in reporting followed by HVAC systems and Misc.Electronic items.

# %% [markdown]
# #Visualization

# %% [markdown]
# #1. Do people Report Products with more value earlier compared to Products with less value?

# %%
prod_d1 = pd.DataFrame(data3.groupby('Product Insured')['Claim Amount'].mean())

# %%
prod_d1
# Out:
#                                                     Claim Amount
# Product Insured
# Cameras and other Misc. Security Equipment            293.572886
# Fixtures                                              188.192451
# Furniture                                            1523.551721
# Heating, ventilation, and air conditioning (HVA...   3231.867405
# Inventory - Finished Goods                             66.480419
# Inventory - Raw Material                              473.891093
# Misc. Electrical Equipment                            571.112876
# Misc. Electronic Items                                305.395494
# Misc. Engineering Tools                               448.472967
# Misc. Lab Equipment                                   815.774604
# Misc. Sensors                                         317.258048
# Property, Plant, and Equipment (PPE) Parts            335.089135
# Pumps and Motors                                      324.710029

# %%
a = prod_d.reset_index()

# %%
b = prod_d1.reset_index()

# %%
prod_3 = pd.merge(a,b,how='inner')

# %%
prod_3
# Out:
#                                       Product Insured  Days_for_claim_request  \
# 0          Cameras and other Misc. Security Equipment                    63.0
# 1                                            Fixtures                    71.0
# 2                                           Furniture                    79.0
# 3   Heating, ventilation, and air conditioning (HV...                    83.0
# 4                          Inventory - Finished Goods                    73.0
# 5                            Inventory - Raw Material                    77.0
# 6                          Misc. Electrical Equipment                    75.0
# 7                              Misc. Electronic Items                    83.0
# 8                             Misc. Engineering Tools                    75.0
# 9                                 Misc. Lab Equipment                    75.0
# 10                                      Misc. Sensors                    73.0
# 11         Property, Plant, and Equipment (PPE) Parts                    85.0
# 12                                   Pumps and Motors                    77.0
#
#     Claim Amount
# 0     293.572886
# 1     188.192451
# 2    1523.551721
# 3    3231.867405
# 4      66.480419
# 5     473.891093
# 6     571.112876
# 7     305.395494
# 8     448.472967
# 9     815.774604
# 10    317.258048
# 11    335.089135
# 12    324.710029

# %%
prod_3['Claim Amount'] = round(prod_3['Claim Amount'],0)

# %%
prod_3
# Out:
#                                       Product Insured  Days_for_claim_request  \
# 0          Cameras and other Misc. Security Equipment                    63.0
# 1                                            Fixtures                    71.0
# 2                                           Furniture                    79.0
# 3   Heating, ventilation, and air conditioning (HV...                    83.0
# 4                          Inventory - Finished Goods                    73.0
# 5                            Inventory - Raw Material                    77.0
# 6                          Misc. Electrical Equipment                    75.0
# 7                              Misc. Electronic Items                    83.0
# 8                             Misc. Engineering Tools                    75.0
# 9                                 Misc. Lab Equipment                    75.0
# 10                                      Misc. Sensors                    73.0
# 11         Property, Plant, and Equipment (PPE) Parts                    85.0
# 12                                   Pumps and Motors                    77.0
#
#     Claim Amount
# 0          294.0
# 1          188.0
# 2         1524.0
# 3         3232.0
# 4           66.0
# 5          474.0
# 6          571.0
# 7          305.0
# 8          448.0
# 9          816.0
# 10         317.0
# 11         335.0
# 12         325.0

# %%
fig2 = px.bar(prod_3,x='Product Insured',y='Claim Amount',text_auto=True,color='Days_for_claim_request')
fig2.update_layout(title='Do people Report Products with more value earlier compared to Products with less value?',xaxis_title='Type of products',yaxis_title='Average claim amount',font=dict(
        family="TimesNewRoman",
        size=18,
        color="Black"))
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c666350b-7723-4de1-8b12-8d81ff26a22a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c666350b-7723-4de1-8b12-8d81ff26a22a")) {                    Plotly.newPlot(                        "c666350b-7723-4de1-8b12-8d81ff26a22a",                        [{"alignmentgroup":"True","hovertemplate":"Product Insured=%{x}<br>Claim Amount=%{y}<br>Days_for_claim_request=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[63.0,71.0,79.0,83.0,73.0,77.0,75.0,83.0,75.0,75.0,73.0,85.0,77.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Cameras and other Misc. Security Equipment","Fixtures","Furniture","Heating, ventilation, and air conditioning (HVAC) System","Inventory - Finished Goods","Inventory - Raw Material","Misc. Electrical Equipment","Misc. Electronic Items","Misc. Engineering Tools","Misc. Lab Equipment","Misc. Sensors","Property, Plant, and Equipment (PPE) Parts","Pumps and Motors"],"xaxis":"x","y":[294.0,188.0,1524.0,3232.0,66.0,474.0,571.0,305.0,448.0,816.0,317.0,335.0,325.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overl ...

# %%
fig2a = px.scatter(prod_3,x='Claim Amount',y='Days_for_claim_request')
fig2a.update_layout(title='To check whether days for request filing depends on the claim amount ',xaxis_title='Claim_amount',yaxis_title='Days for requesting claim',font=dict(
        family="TimesNewRoman",
        size=18,
        color="Black"))
fig2a.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="43d3e1cd-45d9-4508-bf1d-ada4b73adf41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43d3e1cd-45d9-4508-bf1d-ada4b73adf41")) {                    Plotly.newPlot(                        "43d3e1cd-45d9-4508-bf1d-ada4b73adf41",                        [{"hovertemplate":"Claim Amount=%{x}<br>Days_for_claim_request=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[294.0,188.0,1524.0,3232.0,66.0,474.0,571.0,305.0,448.0,816.0,317.0,335.0,325.0],"xaxis":"x","y":[63.0,71.0,79.0,83.0,73.0,77.0,75.0,83.0,75.0,75.0,73.0,85.0,77.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outli ...

# %% [markdown]
# **Insights:**
#
# *   There is no such correlation between the claim amount and days taken to file a request for claim.

# %% [markdown]
# #2.Find if Delay in reporting affects the Percentage of Claim Received ?

# %%
data3
# Out:
#       Claim Number City Code        City          Enterprise Type  \
# 0       DQW1NZO0PL       NSK      Nashik   Public Limited Company
# 1       JS5GAPRN5B       BOM      Mumbai       One Person Company
# 2       ZTSVAQSEAQ       LKO     Lucknow   Public Limited Company
# 3       UJOFDC41EL       DEL       Delhi       One Person Company
# 4       IXZ4B1B9NO       MAA     Chennai  Private Limited Company
# ...            ...       ...         ...                      ...
# 34100   7OSAT7QFWV       CJB  Coimbatore    Joint-Venture Company
# 34101   C0Z4JCRRBX       PNQ        Pune   Public Limited Company
# 34102   83ZTMCMX9D       DEL       Delhi      Sole Proprietorship
# 34103   X3CF6XHWYN       BOM      Mumbai      Sole Proprietorship
# 34104   2T5DKNTRSG       CJB  Coimbatore    Joint-Venture Company
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34100    Property Loss  In Transit
# 34101  Property Damage  In Transit
# 34102  Property Damage  In Transit
# 34103  Property Damage  In Transit
# 34104  Property Damage  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 4                         Misc. Engineering Tools    2004-09-21    2004-11-16
# ...                                           ...           ...           ...
# 34100                    Inventory - Raw Material    2005-09-11    2005-10-22
# 34101                  Inventory - Finished Goods    2003-01-04    2003-02-22
# 34102                      Misc. Electronic Items    2005-01-02    2005-01-14
# 34103                    Inventory - Raw Material    2004-03-05    2004-04-17
# 34104                  Misc. Electrical Equipment    2004-03-06    2004-04-05
#
#        Claim Amount  Close Amount      Disposition  Days_for_claim_request
# 0            490.00          0.00             Deny                      13
# 1            300.00        150.00           Settle                      10
# 2             83.98         83.98  Approve in Full                      35
# 3             83.46         41.73           Settle                     133
# 4             52.49         52.49  Approve in Full                      56
# ...             ...           ...              ...                     ...
# 34100         28.50         28.50  Approve in Full                      41
# 34101        150.00        150.00             Deny                      49
# 34102        103.50         40.00           Settle                      12
# 34103        473.50          0.00             Deny                      43
# 34104        570.53          0.00             Deny                      30
#
# [34105 rows x 13 columns]

# %%
prod_d3 = pd.DataFrame(data3.groupby('Product Insured')['Close Amount'].mean())

# %%
prod_d3
# Out:
#                                                     Close Amount
# Product Insured
# Cameras and other Misc. Security Equipment             45.461399
# Fixtures                                               38.007765
# Furniture                                             240.924756
# Heating, ventilation, and air conditioning (HVA...    193.431719
# Inventory - Finished Goods                             14.846329
# Inventory - Raw Material                              121.626565
# Misc. Electrical Equipment                            117.034350
# Misc. Electronic Items                                 44.640365
# Misc. Engineering Tools                                80.076299
# Misc. Lab Equipment                                    99.245209
# Misc. Sensors                                          73.763454
# Property, Plant, and Equipment (PPE) Parts             87.401902
# Pumps and Motors                                      135.500039

# %%
c = prod_d3.reset_index()

# %%
d = pd.merge(prod_3,c,how='inner')

# %%
d
# Out:
#                                       Product Insured  Days_for_claim_request  \
# 0          Cameras and other Misc. Security Equipment                    63.0
# 1                                            Fixtures                    71.0
# 2                                           Furniture                    79.0
# 3   Heating, ventilation, and air conditioning (HV...                    83.0
# 4                          Inventory - Finished Goods                    73.0
# 5                            Inventory - Raw Material                    77.0
# 6                          Misc. Electrical Equipment                    75.0
# 7                              Misc. Electronic Items                    83.0
# 8                             Misc. Engineering Tools                    75.0
# 9                                 Misc. Lab Equipment                    75.0
# 10                                      Misc. Sensors                    73.0
# 11         Property, Plant, and Equipment (PPE) Parts                    85.0
# 12                                   Pumps and Motors                    77.0
#
#     Claim Amount  Close Amount
# 0          294.0     45.461399
# 1          188.0     38.007765
# 2         1524.0    240.924756
# 3         3232.0    193.431719
# 4           66.0     14.846329
# 5          474.0    121.626565
# 6          571.0    117.034350
# 7          305.0     44.640365
# 8          448.0     80.076299
# 9          816.0     99.245209
# 10         317.0     73.763454
# 11         335.0     87.401902
# 12         325.0    135.500039

# %%
d['Per_of_claim'] = round((d['Close Amount']/d['Claim Amount'])*100,2)

# %%
d
# Out:
#                                       Product Insured  Days_for_claim_request  \
# 0          Cameras and other Misc. Security Equipment                    63.0
# 1                                            Fixtures                    71.0
# 2                                           Furniture                    79.0
# 3   Heating, ventilation, and air conditioning (HV...                    83.0
# 4                          Inventory - Finished Goods                    73.0
# 5                            Inventory - Raw Material                    77.0
# 6                          Misc. Electrical Equipment                    75.0
# 7                              Misc. Electronic Items                    83.0
# 8                             Misc. Engineering Tools                    75.0
# 9                                 Misc. Lab Equipment                    75.0
# 10                                      Misc. Sensors                    73.0
# 11         Property, Plant, and Equipment (PPE) Parts                    85.0
# 12                                   Pumps and Motors                    77.0
#
#     Claim Amount  Close Amount  Per_of_claim
# 0          294.0     45.461399         15.46
# 1          188.0     38.007765         20.22
# 2         1524.0    240.924756         15.81
# 3         3232.0    193.431719          5.98
# 4           66.0     14.846329         22.49
# 5          474.0    121.626565         25.66
# 6          571.0    117.034350         20.50
# 7          305.0     44.640365         14.64
# 8          448.0     80.076299         17.87
# 9          816.0     99.245209         12.16
# 10         317.0     73.763454         23.27
# 11         335.0     87.401902         26.09
# 12         325.0    135.500039         41.69

# %%
fig3 = px.scatter(d,x='Days_for_claim_request',y='Per_of_claim',color='Close Amount')
fig3.update_layout(title='Find if Delay in reporting affects the Percentage of Claim Received',xaxis_title='Delay_in_reporting',yaxis_title='Avg_per_claim',font=dict(
        family="TimesNewRoman",
        size=18,
        color="Black"))
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b1570ab2-e86b-42ad-b50d-a13aec46df27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1570ab2-e86b-42ad-b50d-a13aec46df27")) {                    Plotly.newPlot(                        "b1570ab2-e86b-42ad-b50d-a13aec46df27",                        [{"hovertemplate":"Days_for_claim_request=%{x}<br>Per_of_claim=%{y}<br>Close Amount=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[45.46139941690962,38.00776525821596,240.92475609756096,193.43171931083992,14.846329418849743,121.62656512086829,117.03434974533106,44.64036541889483,80.076298563692,99.24520863309353,73.76345423143351,87.40190201729106,135.50003902439025],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[63.0,71.0,79.0,83.0,73.0,77.0,75.0,83.0,75.0,75.0,73.0,85.0,77.0],"xaxis":"x","y":[15.46,20.22,15.81,5.98,22.49,25.66,20.5,14.64,17.87,12.16,23.27,26.09,41.69],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"ou ...

# %% [markdown]
# **Insights:**
#
# There is no such correlation between the average percentage of claim amount
# and days taken to file a request for claim

# %% [markdown]
# #How claim type and filed Claim Amount could affect the settlement of claim Amount?

# %%
data3
# Out:
#       Claim Number City Code        City          Enterprise Type  \
# 0       DQW1NZO0PL       NSK      Nashik   Public Limited Company
# 1       JS5GAPRN5B       BOM      Mumbai       One Person Company
# 2       ZTSVAQSEAQ       LKO     Lucknow   Public Limited Company
# 3       UJOFDC41EL       DEL       Delhi       One Person Company
# 4       IXZ4B1B9NO       MAA     Chennai  Private Limited Company
# ...            ...       ...         ...                      ...
# 34100   7OSAT7QFWV       CJB  Coimbatore    Joint-Venture Company
# 34101   C0Z4JCRRBX       PNQ        Pune   Public Limited Company
# 34102   83ZTMCMX9D       DEL       Delhi      Sole Proprietorship
# 34103   X3CF6XHWYN       BOM      Mumbai      Sole Proprietorship
# 34104   2T5DKNTRSG       CJB  Coimbatore    Joint-Venture Company
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34100    Property Loss  In Transit
# 34101  Property Damage  In Transit
# 34102  Property Damage  In Transit
# 34103  Property Damage  In Transit
# 34104  Property Damage  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 4                         Misc. Engineering Tools    2004-09-21    2004-11-16
# ...                                           ...           ...           ...
# 34100                    Inventory - Raw Material    2005-09-11    2005-10-22
# 34101                  Inventory - Finished Goods    2003-01-04    2003-02-22
# 34102                      Misc. Electronic Items    2005-01-02    2005-01-14
# 34103                    Inventory - Raw Material    2004-03-05    2004-04-17
# 34104                  Misc. Electrical Equipment    2004-03-06    2004-04-05
#
#        Claim Amount  Close Amount      Disposition  Days_for_claim_request
# 0            490.00          0.00             Deny                      13
# 1            300.00        150.00           Settle                      10
# 2             83.98         83.98  Approve in Full                      35
# 3             83.46         41.73           Settle                     133
# 4             52.49         52.49  Approve in Full                      56
# ...             ...           ...              ...                     ...
# 34100         28.50         28.50  Approve in Full                      41
# 34101        150.00        150.00             Deny                      49
# 34102        103.50         40.00           Settle                      12
# 34103        473.50          0.00             Deny                      43
# 34104        570.53          0.00             Deny                      30
#
# [34105 rows x 13 columns]

# %%
prod4 = data3.groupby('Claim Type')[['Claim Amount','Close Amount']].mean()

# %%
d4 = pd.DataFrame(prod4)

# %%
d4
# Out:
#                  Claim Amount  Close Amount
# Claim Type
# Property Damage    385.853771    103.528882
# Property Loss      919.994480    105.726659

# %%
d4['Per_of_claim'] = round((d4['Close Amount']/d4['Claim Amount'])*100,2)

# %%
d4
# Out:
#                  Claim Amount  Close Amount  Per_of_claim
# Claim Type
# Property Damage    385.853771    103.528882         26.83
# Property Loss      919.994480    105.726659         11.49

# %%
d4 = d4.reset_index()

# %%
fig4 = px.bar(d4,x='Claim Type',y='Per_of_claim',color='Claim Amount',text_auto=True)
fig4.update_layout(title='How claim type and filed Claim Amount could affect the settlement of claim Amount?',xaxis_title='Claim_type',yaxis_title='Avg_per_claim',font=dict(
        family="TimesNewRoman",
        size=18,
        color="Black"))
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="48a5d4f4-9063-4dc5-b163-fe1171b065c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48a5d4f4-9063-4dc5-b163-fe1171b065c5")) {                    Plotly.newPlot(                        "48a5d4f4-9063-4dc5-b163-fe1171b065c5",                        [{"alignmentgroup":"True","hovertemplate":"Claim Type=%{x}<br>Per_of_claim=%{y}<br>Claim Amount=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[385.85377055538316,919.9944802715316],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Property Damage","Property Loss"],"xaxis":"x","y":[26.83,11.49],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"typ ...

# %% [markdown]
# **Insights:**
#
#
# * We can see that property damage has more percentage in settlement of claims compared to property loss.(i.e. if there is a property damage there are high chances that someone gets a claim settlement compared to property loss).

# %% [markdown]
# #Which City has reported the highest number of incidents ?

# %%
data3
# Out:
#       Claim Number City Code        City          Enterprise Type  \
# 0       DQW1NZO0PL       NSK      Nashik   Public Limited Company
# 1       JS5GAPRN5B       BOM      Mumbai       One Person Company
# 2       ZTSVAQSEAQ       LKO     Lucknow   Public Limited Company
# 3       UJOFDC41EL       DEL       Delhi       One Person Company
# 4       IXZ4B1B9NO       MAA     Chennai  Private Limited Company
# ...            ...       ...         ...                      ...
# 34100   7OSAT7QFWV       CJB  Coimbatore    Joint-Venture Company
# 34101   C0Z4JCRRBX       PNQ        Pune   Public Limited Company
# 34102   83ZTMCMX9D       DEL       Delhi      Sole Proprietorship
# 34103   X3CF6XHWYN       BOM      Mumbai      Sole Proprietorship
# 34104   2T5DKNTRSG       CJB  Coimbatore    Joint-Venture Company
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34100    Property Loss  In Transit
# 34101  Property Damage  In Transit
# 34102  Property Damage  In Transit
# 34103  Property Damage  In Transit
# 34104  Property Damage  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 4                         Misc. Engineering Tools    2004-09-21    2004-11-16
# ...                                           ...           ...           ...
# 34100                    Inventory - Raw Material    2005-09-11    2005-10-22
# 34101                  Inventory - Finished Goods    2003-01-04    2003-02-22
# 34102                      Misc. Electronic Items    2005-01-02    2005-01-14
# 34103                    Inventory - Raw Material    2004-03-05    2004-04-17
# 34104                  Misc. Electrical Equipment    2004-03-06    2004-04-05
#
#        Claim Amount  Close Amount      Disposition  Days_for_claim_request
# 0            490.00          0.00             Deny                      13
# 1            300.00        150.00           Settle                      10
# 2             83.98         83.98  Approve in Full                      35
# 3             83.46         41.73           Settle                     133
# 4             52.49         52.49  Approve in Full                      56
# ...             ...           ...              ...                     ...
# 34100         28.50         28.50  Approve in Full                      41
# 34101        150.00        150.00             Deny                      49
# 34102        103.50         40.00           Settle                      12
# 34103        473.50          0.00             Deny                      43
# 34104        570.53          0.00             Deny                      30
#
# [34105 rows x 13 columns]

# %%
d5 = pd.DataFrame(data3.groupby('City')['Claim Number'].count().sort_values(ascending=False))

# %%
d5
# Out:
#                Claim Number
# City
# Mumbai                 2562
# Delhi                  2356
# Bangalore              2160
# Hyderabad              2087
# Chennai                1742
# Pune                   1704
# Ahmedabad              1692
# Lucknow                1646
# Kolkata                1583
# Surat                  1516
# Jaipur                 1425
# Kanpur                 1353
# Nagpur                 1351
# Indore                 1267
# Coimbatore             1201
# Thane                  1182
# Bhopal                 1161
# Patna                  1088
# Visakhapatnam          1084
# Agra                   1036
# Vadodara               1016
# Nashik                 1004
# Amritsar                889

# %%
fig5 = px.bar(d5,text_auto=True)
fig5.update_layout(title='Which City has reported the highest number of incidents ?',xaxis_title='Cities',yaxis_title='No_of_claims',font=dict(
        family="TimesNewRoman",
        size=18,
        color="Black"))
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3025b666-d4b5-4f13-9cde-1759c85fbc04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3025b666-d4b5-4f13-9cde-1759c85fbc04")) {                    Plotly.newPlot(                        "3025b666-d4b5-4f13-9cde-1759c85fbc04",                        [{"alignmentgroup":"True","hovertemplate":"variable=Claim Number<br>City=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Claim Number","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Claim Number","offsetgroup":"Claim Number","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Mumbai","Delhi","Bangalore","Hyderabad","Chennai","Pune","Ahmedabad","Lucknow","Kolkata","Surat","Jaipur","Kanpur","Nagpur","Indore","Coimbatore","Thane","Bhopal","Patna","Visakhapatnam","Agra","Vadodara","Nashik","Amritsar"],"xaxis":"x","y":[2562,2356,2160,2087,1742,1704,1692,1646,1583,1516,1425,1353,1351,1267,1201,1182,1161,1088,1084,1036,1016,1004,889],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker" ...

# %% [markdown]
# Mumbai,Delhi and Bangalore are the top 3 cities in number of claims.

# %% [markdown]
# #Which Type of Claims have the highest number of incidents ?

# %%
d6 = pd.DataFrame(data3.groupby('Claim Type')['Claim Number'].count())

# %%
d6
# Out:
#                  Claim Number
# Claim Type
# Property Damage         12892
# Property Loss           21213

# %%
fig6 = px.bar(d6,text_auto=True)
fig6.update_layout(title='Which Type of Claims have the highest number of incidents ?',xaxis_title='Claim_type',yaxis_title='No_of_incidents',font=dict(
        family="TimesNewRoman",
        size=18,
        color="Black"))
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4791e564-71d2-4e73-957e-c7b0a1d37d7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4791e564-71d2-4e73-957e-c7b0a1d37d7f")) {                    Plotly.newPlot(                        "4791e564-71d2-4e73-957e-c7b0a1d37d7f",                        [{"alignmentgroup":"True","hovertemplate":"variable=Claim Number<br>Claim Type=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Claim Number","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Claim Number","offsetgroup":"Claim Number","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Property Damage","Property Loss"],"xaxis":"x","y":[12892,21213],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"color ...

# %% [markdown]
# **Insights:**
# We can see that property loss has highest number of incidents.

# %% [markdown]
# #Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data3
# Out:
#       Claim Number City Code        City          Enterprise Type  \
# 0       DQW1NZO0PL       NSK      Nashik   Public Limited Company
# 1       JS5GAPRN5B       BOM      Mumbai       One Person Company
# 2       ZTSVAQSEAQ       LKO     Lucknow   Public Limited Company
# 3       UJOFDC41EL       DEL       Delhi       One Person Company
# 4       IXZ4B1B9NO       MAA     Chennai  Private Limited Company
# ...            ...       ...         ...                      ...
# 34100   7OSAT7QFWV       CJB  Coimbatore    Joint-Venture Company
# 34101   C0Z4JCRRBX       PNQ        Pune   Public Limited Company
# 34102   83ZTMCMX9D       DEL       Delhi      Sole Proprietorship
# 34103   X3CF6XHWYN       BOM      Mumbai      Sole Proprietorship
# 34104   2T5DKNTRSG       CJB  Coimbatore    Joint-Venture Company
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34100    Property Loss  In Transit
# 34101  Property Damage  In Transit
# 34102  Property Damage  In Transit
# 34103  Property Damage  In Transit
# 34104  Property Damage  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 4                         Misc. Engineering Tools    2004-09-21    2004-11-16
# ...                                           ...           ...           ...
# 34100                    Inventory - Raw Material    2005-09-11    2005-10-22
# 34101                  Inventory - Finished Goods    2003-01-04    2003-02-22
# 34102                      Misc. Electronic Items    2005-01-02    2005-01-14
# 34103                    Inventory - Raw Material    2004-03-05    2004-04-17
# 34104                  Misc. Electrical Equipment    2004-03-06    2004-04-05
#
#        Claim Amount  Close Amount      Disposition  Days_for_claim_request
# 0            490.00          0.00             Deny                      13
# 1            300.00        150.00           Settle                      10
# 2             83.98         83.98  Approve in Full                      35
# 3             83.46         41.73           Settle                     133
# 4             52.49         52.49  Approve in Full                      56
# ...             ...           ...              ...                     ...
# 34100         28.50         28.50  Approve in Full                      41
# 34101        150.00        150.00             Deny                      49
# 34102        103.50         40.00           Settle                      12
# 34103        473.50          0.00             Deny                      43
# 34104        570.53          0.00             Deny                      30
#
# [34105 rows x 13 columns]

# %%
data3.columns
# Out:
# Index(['Claim Number', 'City Code', 'City', 'Enterprise Type', 'Claim Type',
#        'Claim Site', 'Product Insured', 'Incident Date', 'Date Received',
#        'Claim Amount', 'Close Amount', 'Disposition',
#        'Days_for_claim_request'],
#       dtype='object')

# %% [markdown]
# **Dropping unwanted columns:**
#
#
# *   We can drop the claim number as it is unique.
# *   We can drop either city code or city as both depicts the same
#
#
# *   We can drop the claim amount as it is not related to the target variable
# *   We can drop the dates and keep the days required to file the claim.

# %%
x = data3.drop(['Claim Number', 'City Code','Incident Date', 'Date Received','Close Amount','Disposition','Claim Amount'],1)
# Out:
# <ipython-input-395-64d5720e50d7>:1: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.

# %%
data3['Disposition'].value_counts(normalize=True) #To check the balance of the target variable
# Out:
# Deny               0.523237
# Approve in Full    0.265416
# Settle             0.211347
# Name: Disposition, dtype: float64

# %%
y = data3['Disposition']

# %%
x
# Out:
#              City          Enterprise Type       Claim Type  Claim Site  \
# 0          Nashik   Public Limited Company    Property Loss  In Transit
# 1          Mumbai       One Person Company    Property Loss  In Transit
# 2         Lucknow   Public Limited Company    Property Loss  In Transit
# 3           Delhi       One Person Company    Property Loss  In Transit
# 4         Chennai  Private Limited Company    Property Loss  In Transit
# ...           ...                      ...              ...         ...
# 34100  Coimbatore    Joint-Venture Company    Property Loss  In Transit
# 34101        Pune   Public Limited Company  Property Damage  In Transit
# 34102       Delhi      Sole Proprietorship  Property Damage  In Transit
# 34103      Mumbai      Sole Proprietorship  Property Damage  In Transit
# 34104  Coimbatore    Joint-Venture Company  Property Damage  In Transit
#
#                                   Product Insured  Days_for_claim_request
# 0                        Inventory - Raw Material                      13
# 1      Cameras and other Misc. Security Equipment                      10
# 2                                        Fixtures                      35
# 3                         Misc. Engineering Tools                     133
# 4                         Misc. Engineering Tools                      56
# ...                                           ...                     ...
# 34100                    Inventory - Raw Material                      41
# 34101                  Inventory - Finished Goods                      49
# 34102                      Misc. Electronic Items                      12
# 34103                    Inventory - Raw Material                      43
# 34104                  Misc. Electrical Equipment                      30
#
# [34105 rows x 6 columns]

# %%
encode = LabelEncoder()

# %%
colss = x.columns

# %%
colss
# Out:
# Index(['City', 'Enterprise Type', 'Claim Type', 'Claim Site',
#        'Product Insured', 'Days_for_claim_request'],
#       dtype='object')

# %%
colss1 = ['City', 'Enterprise Type', 'Claim Type', 'Claim Site',
       'Product Insured']

# %%
for i in colss1:
  x[i] = encode.fit_transform(x[i])

# %%
x
# Out:
#        City  Enterprise Type  Claim Type  Claim Site  Product Insured  \
# 0        16               11           1           0                5
# 1        14                5           1           0                0
# 2        13               11           1           0                1
# 3         7                5           1           0                8
# 4         5                7           1           0                8
# ...     ...              ...         ...         ...              ...
# 34100     6                2           1           0                5
# 34101    18               11           0           0                4
# 34102     7               12           0           0                7
# 34103    14               12           0           0                5
# 34104     6                2           0           0                6
#
#        Days_for_claim_request
# 0                          13
# 1                          10
# 2                          35
# 3                         133
# 4                          56
# ...                       ...
# 34100                      41
# 34101                      49
# 34102                      12
# 34103                      43
# 34104                      30
#
# [34105 rows x 6 columns]

# %%
y
# Out:
# 0                   Deny
# 1                 Settle
# 2        Approve in Full
# 3                 Settle
# 4        Approve in Full
#               ...
# 34100    Approve in Full
# 34101               Deny
# 34102             Settle
# 34103               Deny
# 34104               Deny
# Name: Disposition, Length: 34105, dtype: object

# %%
y = encode.fit_transform(y)

# %%
y
# Out:
# array([1, 2, 0, ..., 2, 1, 1])

# %%
sns.countplot(x='Disposition',data=data3)
# Out:
# <Axes: xlabel='Disposition', ylabel='count'>

# %% [markdown]
# To chech whether the target is balanced or not. We can carry on with the target counts as it is not that unbalanced.

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=234,stratify=y)

# %%
y_test.shape
# Out:
# (8527,)

# %% [markdown]
# #Hyper parameter tuning and Model building

# %% [markdown]
# I have used RandomizedSearchcv instead of GridsearchCV because the latter took too much computation time.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %% [markdown]
# Decision Tree

# %%
model_DT = DecisionTreeClassifier(random_state=30)
params = {'max_depth': range(1,20),'max_leaf_nodes':range(1,20),'min_samples_leaf':range(2,30),'min_samples_split':range(4,40),'criterion':['gini','entropy']}
random_DT = RandomizedSearchCV(model_DT,param_distributions=params, cv=5,scoring='accuracy',return_train_score=True,random_state=30)
random_DT.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=30),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': range(1, 20),
#                                         'max_leaf_nodes': range(1, 20),
#                                         'min_samples_leaf': range(2, 30),
#                                         'min_samples_split': range(4, 40)},
#                    random_state=30, return_train_score=True,
#                    scoring='accuracy')

# %%
best_params_DT = random_DT.best_params_
best_params_DT
# Out:
# {'min_samples_split': 15,
#  'min_samples_leaf': 14,
#  'max_leaf_nodes': 18,
#  'max_depth': 7,
#  'criterion': 'entropy'}

# %%
model_cart = DecisionTreeClassifier(criterion='entropy',min_samples_leaf=18,min_samples_split=7,max_depth=16,max_leaf_nodes=20)
model_cart.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=16, max_leaf_nodes=20,
#                        min_samples_leaf=18, min_samples_split=7)

# %%
y_pred_cart_train = model_cart.predict(x_train)

# %%
from sklearn.tree import plot_tree

# %%
x.columns
# Out:
# Index(['City', 'Enterprise Type', 'Claim Type', 'Claim Site',
#        'Product Insured', 'Days_for_claim_request'],
#       dtype='object')

# %%
fn = ['City', 'Enterprise Type', 'Claim Type', 'Claim Site',
       'Product Insured', 'Claim Amount', 'Days_for_claim_request']
cn = ['0','1','2']
fig,axes = plt.subplots(ncols=1,nrows=1,figsize=(10,8),dpi=300)
plot_tree(model_cart,feature_names=fn, class_names=cn,filled=True)
# Out:
# [Text(0.4110824742268041, 0.9375, 'Product Insured <= 3.5\nentropy = 1.471\nsamples = 25578\nvalue = [6789, 13383, 5406]\nclass = 1'),
#  Text(0.20618556701030927, 0.8125, 'Claim Type <= 0.5\nentropy = 1.259\nsamples = 5429\nvalue = [740, 3571, 1118]\nclass = 1'),
#  Text(0.08247422680412371, 0.6875, 'Claim Site <= 0.5\nentropy = 1.49\nsamples = 1286\nvalue = [320, 656, 310]\nclass = 1'),
#  Text(0.041237113402061855, 0.5625, 'entropy = 1.173\nsamples = 560\nvalue = [81, 394, 85]\nclass = 1'),
#  Text(0.12371134020618557, 0.5625, 'Product Insured <= 2.5\nentropy = 1.582\nsamples = 726\nvalue = [239, 262, 225]\nclass = 1'),
#  Text(0.08247422680412371, 0.4375, 'entropy = 1.578\nsamples = 666\nvalue = [197, 251, 218]\nclass = 1'),
#  Text(0.16494845360824742, 0.4375, 'entropy = 1.171\nsamples = 60\nvalue = [42, 11, 7]\nclass = 0'),
#  Text(0.32989690721649484, 0.6875, 'Claim Site <= 1.5\nentropy = 1.152\nsamples = 4143\nvalue = [420, 2915, 808]\nclass = 1'),
#  Text(0.28865979381443296, 0.5625, 'Product Insured <= 2.5\nentropy = 1.146\nsamples = 3478\nvalue = [315, 2435, 728]\nclass = 1'),
#  Text(0.24742268041237114, 0.4375, 'Product Insured <= 1.5\nentropy = 1.036\nsamples = 1937\nvalue = [119, 1429, 389]\nclass = 1'),
#  Text(0.20618556701030927, 0.3125, 'entropy = 1.293\nsamples = 798\nvalue = [96, 499, 203]\nclass = 1'),
#  Text(0.28865979381443296, 0.3125, 'City <= 3.5\nentropy = 0.779\nsamples = 1139\nvalue = [23, 930, 186]\nclass = 1'),
#  Text(0.24742268041237114, 0.1875, 'entropy = 1.073\nsamples = 169\nvalue = [5, 111, 53]\nclass = 1'),
#  Text(0.32989690721649484, 0.1875, 'entropy = 0.706\nsamples = 970\nvalue = [18, 819, 133]\nclass = 1'),
#  Text(0.32989690721649484, 0.4375, 'entropy = 1.261\nsamples = 1541\nvalue = [196, 1006, 339]\nclass = 1'),
#  Text(0.3711340206185567, 0.5625, 'entropy = 1.127\nsamples = 665\nvalue = [105, 480, 80]\nclass = 1'),
#  Text(0.615979381443299, 0.8125, 'Product Insured <= 4.5\nentropy = 1.502\nsamples = 20149\nvalue = [6049, 9812, 4288]\nclass = 1'),
#  Text(0.4948453608247423, 0.6875, 'Claim Type <= 0.5\nentropy = 1.215\nsamples = 2456\nvalue = [1116, 1232, 108]\nclass = 1'),
#  Text(0.4536082474226804, 0.5625, 'entropy = 1.176\nsamples = 819\nvalue = [196, 554, 69]\nclass = 1'),
#  Text(0.5360824742268041, 0.5625, 'entropy = 1.122\nsamples = 1637\nvalue = [920, 678, 39]\nclass = 0'),
#  Text(0.7371134020618557, 0.6875, 'Claim Site <= 1.5\nentropy = 1.512\nsamples = 17693\nvalue = [4933, 8580, 4180]\nclass = 1'),
#  Text(0.6185567010309279, 0.5625, 'Product Insured <= 5.5\nentropy = 1.506\nsamples = 15214\nvalue = [3937, 7517, 3760]\nclass = 1'),
#  Text(0.5051546391752577, 0.4375, 'Claim Type <= 0.5\nentropy = 1.526\nsamples = 5410\nvalue = [1806, 2428, 1176]\nclass = 1'),
#  Text(0.4639175257731959, 0.3125, 'entropy = 1.5\nsamples = 1813\nvalue = [705, 780, 328]\nclass = 1'),
#  Text(0.5463917525773195, 0.3125, 'entropy = 1.53\nsamples = 3597\nvalue = [1101, 1648, 848]\nclass = 1'),
#  Text(0.7319587628865979, 0.4375, 'Product Insured <= 6.5\nentropy = 1.477\nsamples = 9804\nvalue = [2131, 5089, 2584]\nclass = 1'),
#  Text(0.6288659793814433, 0.3125, 'City <= 4.5\nentropy = 1.268\nsamples = 1951\nvalue = [156, 1152, 643]\nclass = 1'),
#  Text(0.5876288659793815, 0.1875, 'entropy = 1.274\nsamples = 410\nvalue = [26, 205, 179]\nclass = 1'),
#  Text(0.6701030927835051, 0.1875, 'entropy = 1.254\nsamples = 1541\nvalue = [130, 947, 464]\nclass = 1'),
#  Text(0.8350515463917526, 0.3125, 'Product Insured <= 7.5\nentropy = 1.499\nsamples = 7853\nvalue = [1975, 3937, 1941]\nclass = 1'),
#  Text(0.7525773195876289, 0.1875, 'Claim Type <= 0.5\nentropy = 1.486\nsamples = 3961\nvalue = [857, 2016, 1088]\nclass = 1'),
#  Text(0.711340206185567, 0.0625, 'entropy = 1.489\nsamples = 3704\nvalue = [787, 1866, 1051]\nclass = 1'),
#  Text(0.7938144329896907, 0.0625, 'entropy = 1.367\nsamples = 257\nvalue = [70, 150, 37]\nclass = 1'),
#  Text(0.9175257731958762, 0.1875, 'Product Insured <= 8.5\nentropy = 1.5\nsamples = 3892\nvalue = [1118, 1921, 853]\nclass = 1'),
#  Text(0.8762886597938144, 0.0625, 'entropy = 1.514\nsamples = 2700\nvalue = [873, 1256, 571]\nclass = 1'),
#  Text(0.9587628865979382, 0.0625, 'entropy = 1.431\nsamples = 1192\nvalue = [245, 665, 282]\nclass = 1'),
#  Text(0.8556701030927835, 0.5625, 'Claim Type <= 0.5\nentropy = 1.486\nsamples = 2479\nvalue = [996, 1063, 420]\nclass = 1'),
#  Text(0.8144329896907216, 0.4375, 'entropy = 1.468\nsamples = 1214\nvalue = [640, 313, 261]\nclass = 0'),
#  Text(0.8969072164948454, 0.4375, 'entropy = 1.338\nsamples = 1265\nvalue = [356, 750, 159]\nclass = 1')]

# %%
from sklearn.metrics import accuracy_score

# %%
accu_DT_train = accuracy_score(y_train,y_pred_cart_train)
accu_DT_train*100
# Out:
# 54.66807412620221

# %%
y_pred_DT = model_cart.predict(x_test)

# %%
accu_DT_test = np.mean(y_test==y_pred_DT)*100

# %%
accu_DT_test
# Out:
# 54.966576756186235

# %%
from sklearn.model_selection import cross_val_score
cv_dt = cross_val_score(model_cart, x_train, y_train, scoring='accuracy')
cv_dt.mean()*100
# Out:
# 54.60550115139134

# %%
from sklearn.metrics import classification_report,recall_score

# %%
cls_cart = classification_report(y_pred_DT, y_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.

# %%
print(cls_cart)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.56      0.34      1004
#            1       0.92      0.55      0.69      7523
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.55      8527
#    macro avg       0.39      0.37      0.34      8527
# weighted avg       0.84      0.55      0.65      8527

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
cm_dt = confusion_matrix(y_test, y_pred_DT)

# %%
cm_dt_df = pd.DataFrame(cm_dt)

# %%
cm_dt1 = ConfusionMatrixDisplay(cm_dt,display_labels=['Approved','Deny','Settle'])

# %%
cm_dt1.plot()

# %% [markdown]
# #Bayes theorem

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model_NB = GaussianNB(var_smoothing=0.007)
model_CNB = MultinomialNB()
model_NB.fit(x_train,y_train)
model_CNB.fit(x_train,y_train)
y_pred_nb_train = model_NB.predict(x_train)
y_pred_nb_test = model_NB.predict(x_test)
accu_nb_train = np.mean(y_train==y_pred_nb_train)*100
accu_nb_test = np.mean(y_test==y_pred_nb_test)*100
print('accu_train_nb:%.3f' % accu_nb_train, '\n', 'accu_test_nb: %.3f' % accu_nb_test)
# Out:
# accu_train_nb:52.322
#  accu_test_nb: 52.328

# %%
cm_nb = confusion_matrix(y_test,y_pred_nb_test)
print(classification_report(y_test,y_pred_nb_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      2263
#            1       0.52      1.00      0.69      4462
#            2       0.00      0.00      0.00      1802
#
#     accuracy                           0.52      8527
#    macro avg       0.17      0.33      0.23      8527
# weighted avg       0.27      0.52      0.36      8527
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
cm_nb1 = ConfusionMatrixDisplay(cm_nb,display_labels=['Approved','Deny','Settle'])
cm_nb1.plot()

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
y_pred_cnb_train = model_CNB.predict(x_train)
y_pred_cnb_test = model_CNB.predict(x_test)
accu_cnb_train = np.mean(y_train==y_pred_cnb_train)*100
accu_cnb_test = np.mean(y_test==y_pred_cnb_test)*100
print('accu_train_cnb:%.3f' % accu_cnb_train, '\n', 'accu_test_cnb: %.3f' % accu_cnb_test)
# Out:
# accu_train_cnb:48.600
#  accu_test_cnb: 48.540

# %%
print(classification_report(y_test,y_pred_cnb_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.18      0.23      2263
#            1       0.53      0.80      0.64      4462
#            2       0.26      0.08      0.12      1802
#
#     accuracy                           0.49      8527
#    macro avg       0.37      0.35      0.33      8527
# weighted avg       0.42      0.49      0.42      8527

# %% [markdown]
# #Random Forest

# %%
model_RF = RandomForestClassifier(random_state=30)
params_rf = {'max_depth': range(1,20),'max_leaf_nodes':range(1,20),'min_samples_leaf':range(2,30),'min_samples_split':range(4,40),'criterion':['gini','entropy'],'n_estimators':range(10,300)}
random_rf = RandomizedSearchCV(model_RF,param_distributions=params_rf,random_state=30,cv=5,scoring='accuracy',return_train_score=True)

# %%
random_rf.fit(x_train,y_train)
random_rf.best_params_
# Out:
# {'n_estimators': 52,
#  'min_samples_split': 24,
#  'min_samples_leaf': 12,
#  'max_leaf_nodes': 19,
#  'max_depth': 14,
#  'criterion': 'gini'}

# %%
model_ranf = RandomForestClassifier(n_estimators=100, min_samples_split=24,max_depth=18,criterion='entropy',bootstrap=True,min_samples_leaf=26,max_leaf_nodes=20, random_state=30)

# %%
model_ranf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=18, max_leaf_nodes=20,
#                        min_samples_leaf=26, min_samples_split=24,
#                        random_state=30)

# %%
y_pred_train_rf = model_ranf.predict(x_train)
accu_rf_train = np.mean(y_train==y_pred_train_rf)*100
accu_rf_train
# Out:
# 53.874423332551416

# %%
y_pred_rf = model_ranf.predict(x_test)
accu_rf_test = np.mean(y_test==y_pred_rf)*100

# %%
accu_rf_test
# Out:
# 53.64137445760525

# %%
fn1 = ['City', 'Enterprise Type', 'Claim Type', 'Claim Site',
       'Product Insured', 'Claim Amount', 'Days_for_claim_request']
cn1 = ['0','1','2']
fig,axes = plt.subplots(ncols=1,nrows=1,figsize=(10,8),dpi=300)
plot_tree(model_ranf.estimators_[7],feature_names=fn1, class_names=cn1,filled=True)
# Out:
# [Text(0.39880952380952384, 0.9375, 'Claim Type <= 0.5\nentropy = 1.473\nsamples = 16170\nvalue = [6878, 13319, 5381]\nclass = 1'),
#  Text(0.14285714285714285, 0.8125, 'Claim Site <= 1.5\nentropy = 1.517\nsamples = 6150\nvalue = [2932, 4623, 2203]\nclass = 1'),
#  Text(0.09523809523809523, 0.6875, 'Product Insured <= 4.5\nentropy = 1.481\nsamples = 4926\nvalue = [2051, 4039, 1738]\nclass = 1'),
#  Text(0.047619047619047616, 0.5625, 'entropy = 1.195\nsamples = 880\nvalue = [264, 982, 178]\nclass = 1'),
#  Text(0.14285714285714285, 0.5625, 'Product Insured <= 5.5\nentropy = 1.519\nsamples = 4046\nvalue = [1787, 3057, 1560]\nclass = 1'),
#  Text(0.09523809523809523, 0.4375, 'City <= 2.5\nentropy = 1.486\nsamples = 1152\nvalue = [718, 779, 305]\nclass = 1'),
#  Text(0.047619047619047616, 0.3125, 'entropy = 1.47\nsamples = 157\nvalue = [126, 81, 45]\nclass = 0'),
#  Text(0.14285714285714285, 0.3125, 'Enterprise Type <= 2.5\nentropy = 1.481\nsamples = 995\nvalue = [592, 698, 260]\nclass = 1'),
#  Text(0.09523809523809523, 0.1875, 'entropy = 1.559\nsamples = 179\nvalue = [105, 112, 71]\nclass = 1'),
#  Text(0.19047619047619047, 0.1875, 'Claim Amount <= 32.5\nentropy = 1.454\nsamples = 816\nvalue = [487, 586, 189]\nclass = 1'),
#  Text(0.14285714285714285, 0.0625, 'entropy = 1.355\nsamples = 335\nvalue = [228, 266, 52]\nclass = 1'),
#  Text(0.23809523809523808, 0.0625, 'entropy = 1.506\nsamples = 481\nvalue = [259, 320, 137]\nclass = 1'),
#  Text(0.19047619047619047, 0.4375, 'entropy = 1.503\nsamples = 2894\nvalue = [1069, 2278, 1255]\nclass = 1'),
#  Text(0.19047619047619047, 0.6875, 'entropy = 1.533\nsamples = 1224\nvalue = [881, 584, 465]\nclass = 0'),
#  Text(0.6547619047619048, 0.8125, 'Claim Site <= 1.5\nentropy = 1.439\nsamples = 10020\nvalue = [3946, 8696, 3178]\nclass = 1'),
#  Text(0.4523809523809524, 0.6875, 'City <= 7.5\nentropy = 1.453\nsamples = 8800\nvalue = [3445, 7492, 2929]\nclass = 1'),
#  Text(0.3333333333333333, 0.5625, 'Product Insured <= 3.5\nentropy = 1.502\nsamples = 3141\nvalue = [1402, 2428, 1103]\nclass = 1'),
#  Text(0.2857142857142857, 0.4375, 'entropy = 1.26\nsamples = 735\nvalue = [135, 751, 276]\nclass = 1'),
#  Text(0.38095238095238093, 0.4375, 'entropy = 1.529\nsamples = 2406\nvalue = [1267, 1677, 827]\nclass = 1'),
#  Text(0.5714285714285714, 0.5625, 'Product Insured <= 3.5\nentropy = 1.419\nsamples = 5659\nvalue = [2043, 5064, 1826]\nclass = 1'),
#  Text(0.47619047619047616, 0.4375, 'City <= 8.5\nentropy = 1.109\nsamples = 1483\nvalue = [208, 1704, 458]\nclass = 1'),
#  Text(0.42857142857142855, 0.3125, 'entropy = 0.796\nsamples = 163\nvalue = [9, 204, 34]\nclass = 1'),
#  Text(0.5238095238095238, 0.3125, 'Claim Amount <= 3.5\nentropy = 1.138\nsamples = 1320\nvalue = [199, 1500, 424]\nclass = 1'),
#  Text(0.47619047619047616, 0.1875, 'entropy = 0.573\nsamples = 51\nvalue = [4, 80, 5]\nclass = 1'),
#  Text(0.5714285714285714, 0.1875, 'entropy = 1.156\nsamples = 1269\nvalue = [195, 1420, 419]\nclass = 1'),
#  Text(0.6666666666666666, 0.4375, 'Product Insured <= 4.5\nentropy = 1.48\nsamples = 4176\nvalue = [1835, 3360, 1368]\nclass = 1'),
#  Text(0.6190476190476191, 0.3125, 'entropy = 1.135\nsamples = 608\nvalue = [536, 419, 25]\nclass = 0'),
#  Text(0.7142857142857143, 0.3125, 'City <= 8.5\nentropy = 1.471\nsamples = 3568\nvalue = [1299, 2941, 1343]\nclass = 1'),
#  Text(0.6666666666666666, 0.1875, 'entropy = 1.268\nsamples = 347\nvalue = [69, 340, 114]\nclass = 1'),
#  Text(0.7619047619047619, 0.1875, 'Enterprise Type <= 0.5\nentropy = 1.485\nsamples = 3221\nvalue = [1230, 2601, 1229]\nclass = 1'),
#  Text(0.7142857142857143, 0.0625, 'entropy = 1.287\nsamples = 81\nvalue = [9, 64, 41]\nclass = 1'),
#  Text(0.8095238095238095, 0.0625, 'entropy = 1.487\nsamples = 3140\nvalue = [1221, 2537, 1188]\nclass = 1'),
#  Text(0.8571428571428571, 0.6875, 'City <= 7.5\nentropy = 1.313\nsamples = 1220\nvalue = [501, 1204, 249]\nclass = 1'),
#  Text(0.8095238095238095, 0.5625, 'entropy = 1.424\nsamples = 362\nvalue = [163, 319, 99]\nclass = 1'),
#  Text(0.9047619047619048, 0.5625, 'Product Insured <= 3.5\nentropy = 1.255\nsamples = 858\nvalue = [338, 885, 150]\nclass = 1'),
#  Text(0.8571428571428571, 0.4375, 'Enterprise Type <= 4.5\nentropy = 1.037\nsamples = 277\nvalue = [59, 336, 48]\nclass = 1'),
#  Text(0.8095238095238095, 0.3125, 'entropy = 0.76\nsamples = 67\nvalue = [19, 96, 2]\nclass = 1'),
#  Text(0.9047619047619048, 0.3125, 'entropy = 1.095\nsamples = 210\nvalue = [40, 240, 46]\nclass = 1'),
#  Text(0.9523809523809523, 0.4375, 'entropy = 1.32\nsamples = 581\nvalue = [279, 549, 102]\nclass = 1')]

# %%
cm_rf = confusion_matrix(y_test,y_pred_rf)

# %%
cm_rf1 = ConfusionMatrixDisplay(cm_rf,display_labels=['Approved','Deny','Settle'])

# %%
cm_rf1.plot()

# %%
cls_rf = classification_report(y_test,y_pred_rf)
print(cls_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.11      0.19      2263
#            1       0.54      0.97      0.69      4462
#            2       0.00      0.00      0.00      1802
#
#     accuracy                           0.54      8527
#    macro avg       0.35      0.36      0.29      8527
# weighted avg       0.42      0.54      0.41      8527
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k_no = range(1,19)
accuracies_knn = []
for i in k_no:
  accuracy_knn = cross_val_score(KNeighborsClassifier(n_neighbors=i),x_train,y_train,cv=5,scoring='accuracy')
  accuracies_knn.append(accuracy_knn.mean())

# %%
accuracies_knn
# Out:
# [0.41539582564274236,
#  0.4239969826133412,
#  0.42559985845491155,
#  0.443388751445449,
#  0.4495661322040297,
#  0.44901869969589203,
#  0.45574335246332015,
#  0.4612559757325073,
#  0.46383621582416,
#  0.4715379347715598,
#  0.47364894372359884,
#  0.473805613959464,
#  0.47697228024398947,
#  0.4819375092191557,
#  0.48056913048363026,
#  0.48518255265714216,
#  0.48768449202356734,
#  0.4870201931035748]

# %%
plt.figure(figsize=(12,8))
plt.plot(k_no, accuracies_knn)
plt.xlabel('k-values')
plt.ylabel('accuracies_knn')
plt.title('Kneighbors vs cv_accuracy')
# Out:
# Text(0.5, 1.0, 'Kneighbors vs cv_accuracy')

# %%
model_KNN = KNeighborsClassifier(n_neighbors=10, metric='euclidean')

# %%
model_KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=10)

# %%
y_pred_knntr = model_KNN.predict(x_train)
y_pred_knnte = model_KNN.predict(x_test)
accu_knn_train = np.mean(y_train==y_pred_knntr)
accu_knn_test = np.mean(y_test==y_pred_knnte)

# %%
accu_knn_train
# Out:
# 0.5747126436781609

# %%
accu_knn_test
# Out:
# 0.47132637504397795

# %%
cm_knn = confusion_matrix(y_test,y_pred_knnte)
cm_knn1 = ConfusionMatrixDisplay(cm_knn, display_labels=['Approved','Deny','Settle'])
cm_knn1.plot()

# %%
print(classification_report(y_test, y_pred_knnte))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.25      0.27      2263
#            1       0.54      0.74      0.63      4462
#            2       0.24      0.08      0.12      1802
#
#     accuracy                           0.47      8527
#    macro avg       0.36      0.36      0.34      8527
# weighted avg       0.42      0.47      0.43      8527

# %%
cv_knn_accu = cross_val_score(model_KNN, x_train, y_train, cv=6, scoring='accuracy')
cv_knn_accu.mean()
# Out:
# 0.4688795058253186

# %% [markdown]
# #Logistic Regression

# %%
params_lr = {'penalty':['l1','l2'],'C':[0.1,10,100],'max_iter':[100,150,250]}
model_lr_hp = LogisticRegression()
random_lr = RandomizedSearchCV(model_lr_hp, param_distributions=params_lr,scoring='accuracy',cv=6,random_state=30)
random_lr.fit(x_train,y_train)
random_lr.best_params_

# %%
model_lr = LogisticRegression(penalty='l2',max_iter=100,C=0.1)

# %%
model_lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression(C=0.1)

# %%
y_pred_lr_train = model_lr.predict(x_train)
y_pred_lr_test = model_lr.predict(x_test)
accu_lr_tr = np.mean(y_train==y_pred_lr_train)
accu_lr_te = np.mean(y_test==y_pred_lr_test)

# %%
accu_lr_tr
# Out:
# 0.5316287434514035

# %%
accu_lr_te
# Out:
# 0.5333646065439193

# %%
cm_lr = confusion_matrix(y_test,y_pred_lr_test)
cm_lr1 = ConfusionMatrixDisplay(cm_lr,display_labels=['Approved','Deny','Settle'])
cm_lr1.plot()

# %%
print(classification_report(y_test,y_pred_lr_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.07      0.13      2263
#            1       0.53      0.98      0.69      4462
#            2       0.00      0.00      0.00      1802
#
#     accuracy                           0.53      8527
#    macro avg       0.35      0.35      0.27      8527
# weighted avg       0.42      0.53      0.40      8527
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# #Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier

# %%
model_gb = GradientBoostingClassifier(random_state=30)
params_gb = {'max_depth': range(1,20),'max_leaf_nodes':range(1,20),'min_samples_leaf':range(2,30),'min_samples_split':range(4,40),'n_estimators':range(10,300)}
gbc = RandomizedSearchCV(model_RF,param_distributions=params_gb,random_state=30,cv=5,scoring='accuracy',return_train_score=True)

# %%
gbc.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=30),
#                    param_distributions={'max_depth': range(1, 20),
#                                         'max_leaf_nodes': range(1, 20),
#                                         'min_samples_leaf': range(2, 30),
#                                         'min_samples_split': range(4, 40),
#                                         'n_estimators': range(10, 300)},
#                    random_state=30, return_train_score=True,
#                    scoring='accuracy')

# %%
gbc.best_params_
# Out:
# {'n_estimators': 52,
#  'min_samples_split': 24,
#  'min_samples_leaf': 12,
#  'max_leaf_nodes': 19,
#  'max_depth': 14}

# %%
model_gb = GradientBoostingClassifier(n_estimators= 77,
 min_samples_split= 30,
 min_samples_leaf=26,
 max_leaf_nodes=17,
 max_depth= 11,
 criterion='squared_error')

# %%
model_gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(criterion='squared_error', max_depth=11,
#                            max_leaf_nodes=17, min_samples_leaf=26,
#                            min_samples_split=30, n_estimators=77)

# %%
y_pred_gb_train = model_gb.predict(x_train)
y_pred_gb_test = model_gb.predict(x_test)
np.mean(y_pred_gb_train==y_train)
# Out:
# 0.5590351082961921

# %%
accu_gb = np.mean(y_pred_gb_test==y_test)

# %%
print(classification_report(y_test,y_pred_gb_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.27      0.36      2263
#            1       0.55      0.91      0.69      4462
#            2       0.31      0.01      0.02      1802
#
#     accuracy                           0.55      8527
#    macro avg       0.47      0.40      0.35      8527
# weighted avg       0.50      0.55      0.46      8527

# %%
cm_gb = confusion_matrix(y_test,y_pred_gb_test)
cm_gb1 = ConfusionMatrixDisplay(cm_gb,display_labels=['Approved','Deny','Settle'])
cm_gb1.plot()

# %% [markdown]
# #Test accuracies

# %%
accu_diction = {'Models':['KNN','Logistic regression', 'Naive Bayes','Multinomial Naive Bayes','Decision Tree','Random forest','Gradient_boosting'],'Test_accuracies':[accu_knn_test*100,accu_lr_te*100,accu_nb_test,accu_cnb_test,accu_DT_test,accu_rf_test,accu_gb*100]}

# %%
accuracy_df = pd.DataFrame(accu_diction)

# %%
accuracy_df
# Out:
#                     Models  Test_accuracies
# 0                      KNN        47.132638
# 1      Logistic regression        53.336461
# 2              Naive Bayes        52.327900
# 3  Multinomial Naive Bayes        48.539932
# 4            Decision Tree        54.966577
# 5            Random forest        53.641374
# 6        Gradient_boosting        55.060396

# %%
re_gb = recall_score(y_test,y_pred_gb_test,average='weighted')

# %%
re_knn = recall_score(y_test,y_pred_knnte,average='weighted')
re_dt = recall_score(y_test,y_pred_DT,average='weighted')
re_lr = recall_score(y_test,y_pred_lr_test,average='weighted')
re_nb = recall_score(y_test,y_pred_nb_test,average='weighted')
re_mnb = recall_score(y_test,y_pred_cnb_test,average='weighted')
re_rf = recall_score(y_test,y_pred_rf,average='weighted')

# %%
re_diction = {'Models':['KNN','Logistic regression', 'Naive Bayes','Multinomial Naive Bayes','Decision Tree','Random forest','Gradient_boosting'],'Recall':[re_knn,re_lr,re_nb,re_mnb,re_dt,re_rf,re_gb]}

# %%
rec_df = pd.DataFrame(re_diction)

# %%
rec_df
# Out:
#                     Models    Recall
# 0                      KNN  0.471326
# 1      Logistic regression  0.533365
# 2              Naive Bayes  0.523279
# 3  Multinomial Naive Bayes  0.485399
# 4            Decision Tree  0.549666
# 5            Random forest  0.536414
# 6        Gradient_boosting  0.550604

# %%
df_res = pd.merge(rec_df,accuracy_df,how='inner')

# %%
df_res
# Out:
#                     Models    Recall  Test_accuracies
# 0                      KNN  0.471326        47.132638
# 1      Logistic regression  0.533365        53.336461
# 2              Naive Bayes  0.523279        52.327900
# 3  Multinomial Naive Bayes  0.485399        48.539932
# 4            Decision Tree  0.549666        54.966577
# 5            Random forest  0.536414        53.641374
# 6        Gradient_boosting  0.550604        55.060396

# %%
data3
# Out:
#       Claim Number City Code        City          Enterprise Type  \
# 0       DQW1NZO0PL       NSK      Nashik   Public Limited Company
# 1       JS5GAPRN5B       BOM      Mumbai       One Person Company
# 2       ZTSVAQSEAQ       LKO     Lucknow   Public Limited Company
# 3       UJOFDC41EL       DEL       Delhi       One Person Company
# 4       IXZ4B1B9NO       MAA     Chennai  Private Limited Company
# ...            ...       ...         ...                      ...
# 34100   7OSAT7QFWV       CJB  Coimbatore    Joint-Venture Company
# 34101   C0Z4JCRRBX       PNQ        Pune   Public Limited Company
# 34102   83ZTMCMX9D       DEL       Delhi      Sole Proprietorship
# 34103   X3CF6XHWYN       BOM      Mumbai      Sole Proprietorship
# 34104   2T5DKNTRSG       CJB  Coimbatore    Joint-Venture Company
#
#             Claim Type  Claim Site  \
# 0        Property Loss  In Transit
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34100    Property Loss  In Transit
# 34101  Property Damage  In Transit
# 34102  Property Damage  In Transit
# 34103  Property Damage  In Transit
# 34104  Property Damage  In Transit
#
#                                   Product Insured Incident Date Date Received  \
# 0                        Inventory - Raw Material    2007-05-25    2007-06-07
# 1      Cameras and other Misc. Security Equipment    2006-09-17    2006-09-27
# 2                                        Fixtures    2006-06-12    2006-07-17
# 3                         Misc. Engineering Tools    2008-07-28    2008-12-08
# 4                         Misc. Engineering Tools    2004-09-21    2004-11-16
# ...                                           ...           ...           ...
# 34100                    Inventory - Raw Material    2005-09-11    2005-10-22
# 34101                  Inventory - Finished Goods    2003-01-04    2003-02-22
# 34102                      Misc. Electronic Items    2005-01-02    2005-01-14
# 34103                    Inventory - Raw Material    2004-03-05    2004-04-17
# 34104                  Misc. Electrical Equipment    2004-03-06    2004-04-05
#
#        Claim Amount  Close Amount      Disposition  Days_for_claim_request
# 0            490.00          0.00             Deny                      13
# 1            300.00        150.00           Settle                      10
# 2             83.98         83.98  Approve in Full                      35
# 3             83.46         41.73           Settle                     133
# 4             52.49         52.49  Approve in Full                      56
# ...             ...           ...              ...                     ...
# 34100         28.50         28.50  Approve in Full                      41
# 34101        150.00        150.00             Deny                      49
# 34102        103.50         40.00           Settle                      12
# 34103        473.50          0.00             Deny                      43
# 34104        570.53          0.00             Deny                      30
#
# [34105 rows x 13 columns]

# %%
data3.to_csv('Merged_dataset.csv')

# %%
df_test
# Out:
#      Claim Number        Incident Date        Date Received City Code  \
# 0      6EYB31JGFR           21-09-2006           26-12-2006       PNQ
# 1      HJLRXONE3R           15-01-2009  2009-11-02 00:00:00       PNQ
# 2      IUOV99JA22           17-08-2005  2005-01-09 00:00:00       AMD
# 3      BGOUHQ2LKK           15-02-2005  2005-01-06 00:00:00       DEL
# 4      HDCG60QET1           17-03-2003  2003-01-04 00:00:00       PNQ
# ...           ...                  ...                  ...       ...
# 3786   IMQYY73AOP           30-07-2007           21-08-2007       CCU
# 3787   2AR1OGIMH4           21-08-2004  2004-09-09 00:00:00       NGP
# 3788   SB4IET2MO5           13-05-2005  2005-02-06 00:00:00       LKO
# 3789   3IBWXQK04L  2004-11-04 00:00:00  2004-04-05 00:00:00       BOM
# 3790   FK8SJ5GWYJ  2004-11-04 00:00:00           23-04-2004       BLR
#
#            City                       Enterprise Type       Claim Type  \
# 0          Pune                    One Person Company    Property Loss
# 1          Pune  Limited Liability Parterneship (LLP)    Property Loss
# 2     Ahmedabad               Private Limited Company    Property Loss
# 3         Delhi                    One Person Company  Property Damage
# 4          Pune               Private Limited Company  Property Damage
# ...         ...                                   ...              ...
# 3786    Kolkata               Private Limited Company    Property Loss
# 3787     Nagpur                   Sole Proprietorship    Property Loss
# 3788    Lucknow                 Joint-Venture Company    Property Loss
# 3789     Mumbai                    One Person Company  Property Damage
# 3790  Bangalore                Public Limited Company    Property Loss
#
#       Claim Site                                    Product Insured
# 0     In Transit                         Inventory - Finished Goods
# 1     In Transit                                           Fixtures
# 2      Warehouse                           Inventory - Raw Material
# 3     In Transit                         Inventory - Finished Goods
# 4     In Transit                             Misc. Electronic Items
# ...          ...                                                ...
# 3786   Warehouse         Cameras and other Misc. Security Equipment
# 3787  In Transit         Property, Plant, and Equipment (PPE) Parts
# 3788   Warehouse  Heating, ventilation, and air conditioning (HV...
# 3789  In Transit                             Misc. Electronic Items
# 3790  In Transit                                          Furniture
#
# [3791 rows x 9 columns]

# %%
df_test['Incident Date'] = pd.to_datetime(df_test['Incident Date'])
df_test['Date Received'] = pd.to_datetime(df_test['Date Received'])

# %%
df_test['Days_for_claim_request'] = abs((df_test['Date Received'] - df_test['Incident Date']).dt.days)

# %%
df_test.columns
# Out:
# Index(['Claim Number', 'Incident Date', 'Date Received', 'City Code', 'City',
#        'Enterprise Type', 'Claim Type', 'Claim Site', 'Product Insured',
#        'Days_for_claim_request'],
#       dtype='object')

# %%
df_test1 = df_test.drop(['Claim Number', 'Incident Date', 'Date Received', 'City Code'],axis=1)

# %%
df_test1.columns
# Out:
# Index(['City', 'Enterprise Type', 'Claim Type', 'Claim Site',
#        'Product Insured', 'Days_for_claim_request'],
#       dtype='object')

# %%
cols_t =['City', 'Enterprise Type', 'Claim Type', 'Claim Site',
       'Product Insured']

# %%
for i in cols_t:
  df_test1[i] = encode.fit_transform(df_test1[i])

# %%
df_test1
# Out:
#       City  Enterprise Type  Claim Type  Claim Site  Product Insured  \
# 0       18                5           1           0                4
# 1       18                3           1           0                1
# 2        1                7           1           2                5
# 3        7                5           0           0                4
# 4       18                7           0           0                7
# ...    ...              ...         ...         ...              ...
# 3786    12                7           1           2                0
# 3787    15               12           1           0               11
# 3788    13                2           1           2                3
# 3789    14                5           0           0                7
# 3790     3               11           1           0                2
#
#       Days_for_claim_request
# 0                         96
# 1                        291
# 2                        220
# 3                         40
# 4                         72
# ...                      ...
# 3786                      22
# 3787                      19
# 3788                      96
# 3789                     213
# 3790                     195
#
# [3791 rows x 6 columns]

# %%
df_test1['Days_for_claim_request'] = abs(df_test1['Days_for_claim_request'])

# %%
pred_test = model_gb.predict(df_test1)

# %%
preds = pd.DataFrame(pred_test)

# %%
preds
# Out:
#       0
# 0     0
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 3786  1
# 3787  1
# 3788  1
# 3789  1
# 3790  1
#
# [3791 rows x 1 columns]

# %%
preds = preds.rename({0:'Predicted'},axis=1)

# %%
preds
# Out:
#       Predicted
# 0             0
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 3786          1
# 3787          1
# 3788          1
# 3789          1
# 3790          1
#
# [3791 rows x 1 columns]

# %%
df_test
# Out:
#      Claim Number Incident Date Date Received City Code       City  \
# 0      6EYB31JGFR    2006-09-21    2006-12-26       PNQ       Pune
# 1      HJLRXONE3R    2009-01-15    2009-11-02       PNQ       Pune
# 2      IUOV99JA22    2005-08-17    2005-01-09       AMD  Ahmedabad
# 3      BGOUHQ2LKK    2005-02-15    2005-01-06       DEL      Delhi
# 4      HDCG60QET1    2003-03-17    2003-01-04       PNQ       Pune
# ...           ...           ...           ...       ...        ...
# 3786   IMQYY73AOP    2007-07-30    2007-08-21       CCU    Kolkata
# 3787   2AR1OGIMH4    2004-08-21    2004-09-09       NGP     Nagpur
# 3788   SB4IET2MO5    2005-05-13    2005-02-06       LKO    Lucknow
# 3789   3IBWXQK04L    2004-11-04    2004-04-05       BOM     Mumbai
# 3790   FK8SJ5GWYJ    2004-11-04    2004-04-23       BLR  Bangalore
#
#                            Enterprise Type       Claim Type  Claim Site  \
# 0                       One Person Company    Property Loss  In Transit
# 1     Limited Liability Parterneship (LLP)    Property Loss  In Transit
# 2                  Private Limited Company    Property Loss   Warehouse
# 3                       One Person Company  Property Damage  In Transit
# 4                  Private Limited Company  Property Damage  In Transit
# ...                                    ...              ...         ...
# 3786               Private Limited Company    Property Loss   Warehouse
# 3787                   Sole Proprietorship    Property Loss  In Transit
# 3788                 Joint-Venture Company    Property Loss   Warehouse
# 3789                    One Person Company  Property Damage  In Transit
# 3790                Public Limited Company    Property Loss  In Transit
#
#                                         Product Insured  \
# 0                            Inventory - Finished Goods
# 1                                              Fixtures
# 2                              Inventory - Raw Material
# 3                            Inventory - Finished Goods
# 4                                Misc. Electronic Items
# ...                                                 ...
# 3786         Cameras and other Misc. Security Equipment
# 3787         Property, Plant, and Equipment (PPE) Parts
# 3788  Heating, ventilation, and air conditioning (HV...
# 3789                             Misc. Electronic Items
# 3790                                          Furniture
#
#       Days_for_claim_request
# 0                         96
# 1                        291
# 2                        220
# 3                         40
# 4                         72
# ...                      ...
# 3786                      22
# 3787                      19
# 3788                      96
# 3789                     213
# 3790                     195
#
# [3791 rows x 10 columns]

# %%
df_test['Disposition_predicted'] = preds

# %%
df_test
# Out:
#      Claim Number Incident Date Date Received City Code       City  \
# 0      6EYB31JGFR    2006-09-21    2006-12-26       PNQ       Pune
# 1      HJLRXONE3R    2009-01-15    2009-11-02       PNQ       Pune
# 2      IUOV99JA22    2005-08-17    2005-01-09       AMD  Ahmedabad
# 3      BGOUHQ2LKK    2005-02-15    2005-01-06       DEL      Delhi
# 4      HDCG60QET1    2003-03-17    2003-01-04       PNQ       Pune
# ...           ...           ...           ...       ...        ...
# 3786   IMQYY73AOP    2007-07-30    2007-08-21       CCU    Kolkata
# 3787   2AR1OGIMH4    2004-08-21    2004-09-09       NGP     Nagpur
# 3788   SB4IET2MO5    2005-05-13    2005-02-06       LKO    Lucknow
# 3789   3IBWXQK04L    2004-11-04    2004-04-05       BOM     Mumbai
# 3790   FK8SJ5GWYJ    2004-11-04    2004-04-23       BLR  Bangalore
#
#                            Enterprise Type       Claim Type  Claim Site  \
# 0                       One Person Company    Property Loss  In Transit
# 1     Limited Liability Parterneship (LLP)    Property Loss  In Transit
# 2                  Private Limited Company    Property Loss   Warehouse
# 3                       One Person Company  Property Damage  In Transit
# 4                  Private Limited Company  Property Damage  In Transit
# ...                                    ...              ...         ...
# 3786               Private Limited Company    Property Loss   Warehouse
# 3787                   Sole Proprietorship    Property Loss  In Transit
# 3788                 Joint-Venture Company    Property Loss   Warehouse
# 3789                    One Person Company  Property Damage  In Transit
# 3790                Public Limited Company    Property Loss  In Transit
#
#                                         Product Insured  \
# 0                            Inventory - Finished Goods
# 1                                              Fixtures
# 2                              Inventory - Raw Material
# 3                            Inventory - Finished Goods
# 4                                Misc. Electronic Items
# ...                                                 ...
# 3786         Cameras and other Misc. Security Equipment
# 3787         Property, Plant, and Equipment (PPE) Parts
# 3788  Heating, ventilation, and air conditioning (HV...
# 3789                             Misc. Electronic Items
# 3790                                          Furniture
#
#       Days_for_claim_request  Disposition_predicted
# 0                         96                      0
# 1                        291                      1
# 2                        220                      1
# 3                         40                      1
# 4                         72                      1
# ...                      ...                    ...
# 3786                      22                      1
# 3787                      19                      1
# 3788                      96                      1
# 3789                     213                      1
# 3790                     195                      1
#
# [3791 rows x 11 columns]

# %%
df_test['Disposition_predicted'].value_counts()
# Out:
# 1    3255
# 0     514
# 2      22
# Name: Disposition_predicted, dtype: int64

# %%
df_test['Disposition_predicted'] = df_test['Disposition_predicted'].map({0:'Approved_in_full',1:'Denied',2:'Settled'})

# %%
df_test
# Out:
#      Claim Number Incident Date Date Received City Code       City  \
# 0      6EYB31JGFR    2006-09-21    2006-12-26       PNQ       Pune
# 1      HJLRXONE3R    2009-01-15    2009-11-02       PNQ       Pune
# 2      IUOV99JA22    2005-08-17    2005-01-09       AMD  Ahmedabad
# 3      BGOUHQ2LKK    2005-02-15    2005-01-06       DEL      Delhi
# 4      HDCG60QET1    2003-03-17    2003-01-04       PNQ       Pune
# ...           ...           ...           ...       ...        ...
# 3786   IMQYY73AOP    2007-07-30    2007-08-21       CCU    Kolkata
# 3787   2AR1OGIMH4    2004-08-21    2004-09-09       NGP     Nagpur
# 3788   SB4IET2MO5    2005-05-13    2005-02-06       LKO    Lucknow
# 3789   3IBWXQK04L    2004-11-04    2004-04-05       BOM     Mumbai
# 3790   FK8SJ5GWYJ    2004-11-04    2004-04-23       BLR  Bangalore
#
#                            Enterprise Type       Claim Type  Claim Site  \
# 0                       One Person Company    Property Loss  In Transit
# 1     Limited Liability Parterneship (LLP)    Property Loss  In Transit
# 2                  Private Limited Company    Property Loss   Warehouse
# 3                       One Person Company  Property Damage  In Transit
# 4                  Private Limited Company  Property Damage  In Transit
# ...                                    ...              ...         ...
# 3786               Private Limited Company    Property Loss   Warehouse
# 3787                   Sole Proprietorship    Property Loss  In Transit
# 3788                 Joint-Venture Company    Property Loss   Warehouse
# 3789                    One Person Company  Property Damage  In Transit
# 3790                Public Limited Company    Property Loss  In Transit
#
#                                         Product Insured  \
# 0                            Inventory - Finished Goods
# 1                                              Fixtures
# 2                              Inventory - Raw Material
# 3                            Inventory - Finished Goods
# 4                                Misc. Electronic Items
# ...                                                 ...
# 3786         Cameras and other Misc. Security Equipment
# 3787         Property, Plant, and Equipment (PPE) Parts
# 3788  Heating, ventilation, and air conditioning (HV...
# 3789                             Misc. Electronic Items
# 3790                                          Furniture
#
#       Days_for_claim_request Disposition_predicted
# 0                         96      Approved_in_full
# 1                        291                Denied
# 2                        220                Denied
# 3                         40                Denied
# 4                         72                Denied
# ...                      ...                   ...
# 3786                      22                Denied
# 3787                      19                Denied
# 3788                      96                Denied
# 3789                     213                Denied
# 3790                     195                Denied
#
# [3791 rows x 11 columns]

# %%
sns.countplot(x='Disposition_predicted',data=df_test)
plt.title('Predicted results using test dataset')
# Out:
# Text(0.5, 1.0, 'Predicted results using test dataset')

# %%
df_predicted = df_test.copy()

# %%
df_predicted.to_csv('Predicted_data.csv')
